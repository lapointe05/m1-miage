# %% [markdown]
# <a href="https://colab.research.google.com/github/lapointe05/m1-miage/blob/Rayene_Hakoume/Copie_de_td_04_to_do.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/fr/0/0b/Polytech_Lyon_logo.png" alt="drawing" height="200"/>
#
# # Algorithmique Avancée & Programmation en Python
# ---

# %% [markdown]
# # TD 04
#
# Intro aux traitement de données
#
# ```python
# print("Hello, friend! It's been a while...")
# ```
#
# Elements à consulter:
#
#
# Doc                                   |             Link
# --------------------------------------|------------------------------------
# Python en 30 jours | [>link<](https://moncoachdata.com/courses/apprendre-python-en-30-jours/)
# Get started with pandas | [>link<](https://colab.research.google.com/notebooks/snippets/pandas.ipynb)

# %% [markdown]
# ## Intro
#
# Le premier bloc devrait toujours contenir les installs/imports dont on aura besoin pour le reste

# %%
# Installs
# !pip install emoji --quiet
# Out:
#      |████████████████████████████████| 240 kB 5.1 MB/s
#   Building wheel for emoji (setup.py) ... done

# %%
# Imports
import os
import json
from random import randint
# import pandas as pd
# import numpy as np
from getpass import getpass
import emoji

print(emoji.emojize('Python is awesome :thumbs_up:'))
# Out:
# Python is awesome 👍

# %% [markdown]
# ##EX01
# ### Liste de dictionnaire
#
# * à partir d'un fichier  [csv](./src/to_do/td_04/netflix_titles.csv)
#
# * en résultat une liste de dicts qui doit contenir le titre de la série, la plateforme de streaming (légal), le nombre d'épisodes de la série, l'année de sortie et une note /10.

# %%
# Code here
# Code here
import csv
f=open("netflix_titles.csv","r",encoding="utf-8")
fich = csv.reader(f)
series = {}
for serie in fich:
    if serie[1]=="TV Show":
        series[serie[0]]= {'Titre de la serie' : serie[2], 'Plateforme de streaming' : serie[8], "Nombre d épisodes" : serie[9], 'Année de sortie': serie[7], 'note /10 \n' : serie[5]}
      
print(series)
# Out:
# {'s2': {'Titre de la serie': 'Blood & Water', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '2 Seasons', 'Année de sortie': '2021', 'note /10 \n': 'South Africa'}, 's3': {'Titre de la serie': 'Ganglands', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's4': {'Titre de la serie': 'Jailbirds New Orleans', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's5': {'Titre de la serie': 'Kota Factory', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '2 Seasons', 'Année de sortie': '2021', 'note /10 \n': 'India'}, 's6': {'Titre de la serie': 'Midnight Mass', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's9': {'Titre de la serie': 'The Great British Baking Show', 'Plateforme de streaming': 'TV-14', 'Nombre d épisodes': '9 Seasons', 'Année de sortie': '2021', 'note /10 \n': 'United Kingdom'}, 's11': {'Titre de la serie': 'Vendetta: Truth, Lies and The Mafia', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's12': {'Titre de la serie': 'Bangkok Breaking', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's15': {'Titre de la serie': 'Crime Stories: India Detectives', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's16': {'Titre de la serie': 'Dear White People', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '4 Seasons', 'Année de sortie': '2021', 'note /10 \n': 'United States'}, 's18': {'Titre de la serie': 'Falsa identidad', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '2 Seasons', 'Année de sortie': '2020', 'note /10 \n': 'Mexico'}, 's20': {'Titre de la serie': 'Jaguar', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's21': {'Titre de la serie': 'Monsters Inside: The 24 Faces of Billy Milligan', 'Plateforme de streaming': 'TV-14', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's22': {'Titre de la serie': 'Resurrection: Ertugrul', 'Plateforme de streaming': 'TV-14', 'Nombre d épisodes': '5 Seasons', 'Année de sortie': '2018', 'note /10 \n': 'Turkey'}, 's26': {'Titre de la serie': 'Love on the Spectrum', 'Plateforme de streaming': 'TV-14', 'Nombre d épisodes': '2 Seasons', 'Année de sortie': '2021', 'note /10 \n': 'Australia'}, 's32': {'Titre de la serie': 'Chicago Party Aunt', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's33': {'Titre de la serie': 'Sex Education', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '3 Seasons', 'Année de sortie': '2020', 'note /10 \n': 'United Kingdom'}, 's34': {'Titre de la serie': 'Squid Game', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': ''}, 's35': {'Titre de la serie': 'Tayo and Little Wizards', 'Plateforme de streaming': 'TV-Y7', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2020', 'note /10 \n': ''}, 's38': {'Titre de la serie': 'Angry Birds', 'Plateforme de streaming': 'TV-Y7', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2018', 'note /10 \n': 'Finland'}, 's40': {'Titre de la serie': 'Chhota Bheem', 'Plateforme de streaming': 'TV-Y7', 'Nombre d épisodes': '3 Seasons', 'Année de sortie': '2021', 'note /10 \n': 'India'}, 's41': {'Titre de la serie': 'He-Man and the Masters of the Universe', 'Plateforme de streaming': 'TV-Y7', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2021', 'note /10 \n': 'United States'}, 's48': {'Titre de la serie': 'The Smart Money Woman', 'Plateforme de streaming': 'TV-MA', 'Nombre d épisodes': '1 Season', 'Année de sortie': '2020', 'note /10 \n': ''}, 's50': {'Titr ...

# %% [markdown]
# # Bonus (Mandatory)

# %% [markdown]
# ## Github
# Pour soumettre votre travail:
#
# 1.   Commit changes to a branch and push to [github](https://google.com)
# 2.   Create pull request / merge request
