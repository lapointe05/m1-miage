# %% [markdown]
# <a href="https://colab.research.google.com/github/lapointe05/m1-miage/blob/Manel_KALLOUD/Manel_KALLOUD_TP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/fr/0/0b/Polytech_Lyon_logo.png" alt="drawing" height="200"/>
#
# # Algorithmique Avancée & Programmation en Python
# ---

# %% [markdown]
# # TD 04
#
# Intro aux traitement de données
#
# ```python
# print("Hello, friend! It's been a while...")
# ```
#
# Elements à consulter:
#
#
# Doc                                   |             Link
# --------------------------------------|------------------------------------
# Python en 30 jours | [>link<](https://moncoachdata.com/courses/apprendre-python-en-30-jours/)
# Get started with pandas | [>link<](https://colab.research.google.com/notebooks/snippets/pandas.ipynb)

# %% [markdown]
# ## Intro
#
# Le premier bloc devrait toujours contenir les installs/imports dont on aura besoin pour le reste

# %%
# Installs
# !pip install emoji --quiet
# Out:
#      |████████████████████████████████| 240 kB 5.1 MB/s
#   Building wheel for emoji (setup.py) ... done

# %%
# Imports
import os
import json
from random import randint
# import pandas as pd
# import numpy as np
from getpass import getpass
import emoji

print(emoji.emojize('Python is awesome :thumbs_up:'))
# Out:
# Python is awesome 👍

# %% [markdown]
# ##EX01
# ### Liste de dictionnaire
#
# * à partir d'un fichier  [csv](./td_04)
#
#
#
# * en résultat une liste de dicts qui doit contenir le titre de la série, la plateforme de streaming (légal), le nombre d'épisodes de la série, l'année de sortie et une note /10.

# %%
# Chemmin d'accès au fichier csv
import csv

# Ouvrir le fichier csv
with open('netflix_titles.csv', 'r') as f:
    # Créer un objet csv à partir du fichier
    fich = csv.DictReader(f)
# dictionnaire vide 
    series={}
    for s in fich:
      if (s["type"]=="Movie") == True:
        series["titre"] = s["title"]
        series["Directeur"] = s["director"]
        series["Pays"] = s["country"]
        series["Année de sortie"] = s["release_year"]
        series["Note"] = s["rating"]
        print(series)
    binge_watch_list=[]
   # for i in binge_watch_list

#tout en minuscule
print(type(series))
print()
#qu'une virgule
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# {'titre': 'A Christmas Catch', 'Directeur': '', 'Pays': 'Canada', 'Année de sortie': '2018', 'Note': 'TV-G'}
# {'titre': 'Christmas with a Prince', 'Directeur': 'Justin G. Dyck', 'Pays': 'Canada', 'Année de sortie': '2018', 'Note': 'TV-PG'}
# {'titre': 'Miss India', 'Directeur': 'Narendra Nath', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Felix Lobrecht: Hype', 'Directeur': 'Jan-Peter Horns', 'Pays': 'Germany', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'MOTHER', 'Directeur': 'Tatsushi Omori', 'Pays': 'Japan', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'The Beginning of Life', 'Directeur': 'Estela Renner', 'Pays': '', 'Année de sortie': '2016', 'Note': 'TV-PG'}
# {'titre': 'Ya no estoy aquí: Una conversación entre Guillermo del Toro y Alfonso Cuarón', 'Directeur': '', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Prospect', 'Directeur': 'Zeek Earl, Christopher Caldwell', 'Pays': 'Canada, United States', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'Christmas Break-In', 'Directeur': 'Michael Kampa', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-PG'}
# {'titre': 'Elf Pets: A Fox Cub’s Christmas Tale', 'Directeur': 'Chanda Bell', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Elf Pets: Santa’s Reindeer Rescue', 'Directeur': 'Chanda Bell', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Elliot the Littlest Reindeer', 'Directeur': 'Jennifer Westcott', 'Pays': 'Canada', 'Année de sortie': '2018', 'Note': 'PG'}
# {'titre': 'Little Monsters', 'Directeur': 'Richard Greenberg', 'Pays': 'United States', 'Année de sortie': '1989', 'Note': 'PG'}
# {'titre': 'Mile 22', 'Directeur': 'Peter Berg', 'Pays': 'United States, China, Colombia', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'Piercing', 'Directeur': 'Nicolas Pesce', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'Snowden', 'Directeur': 'Oliver Stone', 'Pays': 'United Kingdom, France, Germany, United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'The Impossible', 'Directeur': 'J.A. Bayona', 'Pays': 'Spain, Thailand, United States', 'Année de sortie': '2012', 'Note': 'PG-13'}
# {'titre': 'The Next Karate Kid', 'Directeur': 'Christopher Cain', 'Pays': 'United States', 'Année de sortie': '1994', 'Note': 'PG'}
# {'titre': 'Wheels of Fortune', 'Directeur': 'Shaun Paul Piccinino', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'The 12th Man', 'Directeur': 'Harald Zwart', 'Pays': 'Norway', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'Hidden in Plain Sight', 'Directeur': 'Stacia Crawford', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'His House', 'Directeur': 'Remi Weekes', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'In Line', 'Directeur': 'Tope Oshin', 'Pays': 'Nigeria', 'Année de sortie': '2017', 'Note': 'TV-14'}
# {'titre': 'Kaali Khuhi', 'Directeur': 'Terrie Samundra', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Rogue City', 'Directeur': 'Olivier Marchal', 'Pays': 'France', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Day of the Lord', 'Directeur': 'Santiago Alvarado Ilarri', 'Pays': 'Mexico, Spain', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Pagpag: Nine Lives', 'Directeur': 'Frasco Mortiz', 'Pays': 'Philippines', 'Année de sortie': '2013', 'Note': 'TV-14'}
# {'titre': 'Holidate', 'Directeur': 'John Whitesell', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'La Gran Ilusión', 'Directeur': 'Antonio Díaz', 'Pays': '', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Metallica Through The Never', 'Directeur': 'Nimród Antal', 'Pays': 'United States', 'Année de sortie': '2013', 'Note': 'R'}
# {'titre': 'Nobody Sleeps in the Woods Tonight', 'Directeur': 'Bartosz M. Kowalski', 'Pays': 'Poland', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Secrets of the Saqqara Tomb', 'Directeur': 'James Tovell', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Guillermo Vilas: Settling the Score', 'Directeur': 'Matías Gueilburt', 'Pays': 'Argentina', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': "Sarah Cooper: Everything's Fine", 'Directeur': 'Natasha Lyonne', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Ajab Prem Ki Ghazab Kahani', 'Directeur': 'Rajkumar Santoshi', 'Pays': 'India', 'Année de sortie': '2009', 'Note': 'TV-14'}
# {'titre': "Black '47", 'Directeur': 'Lance Daly', 'Pays': 'Ireland, Luxembourg, Belgium', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'I Am Woman', 'Directeur': 'Unjoo Moon', 'Pays': 'Australia', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Alice Junior', 'Directeur': 'Gil Baroni', 'Pays': 'Brazil', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Over the Moon', 'Directeur': 'Glen Keane', 'Pays': 'China, United States', 'Année de sortie': '2020', 'Note': 'PG'}
# {'titre': 'Shattered Memories', 'Directeur': 'Chris Sivertson', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'Bending the Arc', 'Directeur': 'Kief Davidson, Pedro Kos', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Cadaver', 'Directeur': 'Jarand Herdal', 'Pays': 'Norway', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Exes Baggage', 'Directeur': 'Dan Villegas', 'Pays': 'Philippines', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': "Fisherman's Friends", 'Directeur': 'Chris Foggin', 'Pays': 'United Kingdom', 'Année de sortie': '2019', 'Note': 'PG-13'}
# {'titre': 'The Hows of Us', 'Directeur': 'Cathy Garcia-Molina', 'Pays': 'Philippines', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'The Hummingbird Project', 'Directeur': 'Kim Nguyen', 'Pays': 'Canada, Belgium', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'Yes, God, Yes', 'Directeur': 'Karen Maine', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Brave Blue World: Racing to Solve Our Water Crisis', 'Directeur': 'Tim Neeves', 'Pays': 'Canada, United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Rebecca', 'Directeur': 'Ben Wheatley', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'PG-13'}
# {'titre': 'The Magic School Bus Rides Again The Frizz Connection', 'Directeur': 'Richard Weston', 'Pays': 'Canada', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Tremors: Shrieker Island', 'Directeur': 'Don Michael Paul', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'PG-13'}
# {'titre': 'Beirut Oh Beirut', 'Directeur': 'Maroun Baghdadi', 'Pays': 'Lebanon', 'Année de sortie': '1975', 'Note': 'TV-14'}
# {'titre': 'Bosta', 'Directeur': 'Philippe Aractingi', 'Pays': 'Lebanon', 'Année de sortie': '2005', 'Note': 'TV-14'}
# {'titre': 'Ghadi', 'Directeur': 'Amin Dora', 'Pays': 'Lebanon', 'Année de sortie': '2013', 'Note': 'TV-MA'}
# {'titre': 'Heritages', 'Directeur': 'Philippe Aractingi', 'Pays': 'Lebanon, United Arab Emirates, France, Switzerland, Germany', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'Listen', 'Directeur': 'Philippe Aractingi', 'Pays': 'Lebanon', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Out of Life', 'Directeur': 'Maroun Baghdadi', 'Pays': 'France, Belgium, Italy', 'Année de sortie': '1991', 'Note': 'TV-MA'}
# {'titre': 'Panoptic', 'Directeur': 'Rana Eid', 'Pays': 'Lebanon', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Taxi Ballad', 'Directeur': 'Daniel Joseph', 'Pays': 'Lebanon, United States, United Arab Emirates', 'Année de sortie': '2012', 'Note': 'TV-MA'}
# {'titre': 'The Kite', 'Directeur': 'Randa Chahal Sabbag', 'Pays': 'Lebanon, France', 'Année de sortie': '2003', 'Note': 'TV-MA'}
# {'titre': 'The Little Wars', 'Directeur': 'Maroun Baghdadi', 'Pays': 'France, Lebanon', 'Année de sortie': '1982', 'Note': 'TV-14'}
# {'titre': 'Under the Bombs', 'Directeur': 'Philippe Aractingi', 'Pays': 'France, Lebanon, United Kingdom', 'Année de sortie': '2007', 'Note': 'TV-MA'}
# {'titre': 'West Beirut', 'Directeur': 'Ziad Doueiri', 'Pays': 'France, Norway, Lebanon, Belgium', 'Année de sortie': '1999', 'Note': 'TV-MA'}
# {'titre': 'What Did I Mess', 'Directeur': 'Shady Hanna', 'Pays': 'Lebanon', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'Whispers', 'Directeur': 'Maroun Baghdadi', 'Pays': 'Lebanon, Canada, France', 'Année de sortie': '1980', 'Note': 'TV-14'}
# {'titre': 'Zozo', 'Directeur': 'Josef Fares', 'Pays': 'Sweden, Czech Republic, United Kingdom, Denmark, Netherlands', 'Année de sortie': '2005', 'Note': 'TV-MA'}
# {'titre': 'ParaNorman', 'Directeur': 'Sam Fell, Chris Butler', 'Pays': 'United States', 'Année de sortie': '2012', 'Note': 'PG'}
# {'titre': 'I Am Vengeance: Retaliation', 'Directeur': 'Ross Boyask', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Disconnect', 'Directeur': "David 'Tosh' Gitonga, Michael Jones", 'Pays': 'Kenya', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'In a Valley of Violence', 'Directeur': 'Ti West', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'The Trial of the Chicago 7', 'Directeur': 'Aaron Sorkin', 'Pays': 'United States, United Kingdom, India', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Unfriended', 'Directeur': 'Levan Gabriadze', 'Pays': 'United States, Russia', 'Année de sortie': '2014', 'Note': 'R'}
# {'titre': "A Babysitter's Guide to Monster Hunting", 'Directeur': 'Rachel Talalay', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Batman: The Killing Joke', 'Directeur': 'Sam Liu', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': "El-Khawaga's Dilemma", 'Directeur': 'Peter Mimi', 'Pays': 'Egypt', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'Kartini: Princess of Java', 'Directeur': 'Hanung Bramantyo', 'Pays': 'Indonesia, Netherlands', 'Année de sortie': '2017', 'Note': 'TV-PG'}
# {'titre': 'Love Like the Falling Rain', 'Directeur': 'Lasja Fauzia Susatyo', 'Pays': 'Indonesia', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Rooting for Roona', 'Directeur': 'Pavitra Chalam, Akshay Shankar', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'A Choo', 'Directeur': 'Kevin Ko, Peter Tsi', 'Pays': 'Taiwan', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'BLACKPINK: Light Up the Sky', 'Directeur': 'Caroline Suh', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'The Three Deaths of Marisela Escobedo', 'Directeur': 'Carlos Pérez Osorio', 'Pays': 'Mexico', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Fida', 'Directeur': 'Ken Ghosh', 'Pays': 'India', 'Année de sortie': '2004', 'Note': 'TV-14'}
# {'titre': 'Octonauts & the Great Barrier Reef', 'Directeur': 'Blair Simmons', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Dil', 'Directeur': 'Indra Kumar', 'Pays': 'India', 'Année de sortie': '1990', 'Note': 'TV-14'}
# {'titre': 'Disco Dancer', 'Directeur': 'B. Subhash', 'Pays': 'India', 'Année de sortie': '1982', 'Note': 'TV-14'}
# {'titre': 'Hunterrr', 'Directeur': 'Harshavardhan Kulkarni', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-MA'}
# {'titre': 'Phir Hera Pheri', 'Directeur': 'Neeraj Vora', 'Pays': 'India', 'Année de sortie': '2006', 'Note': 'TV-14'}
# {'titre': 'The Legend of Bhagat Singh', 'Directeur': 'Rajkumar Santoshi', 'Pays': 'India', 'Année de sortie': '2002', 'Note': 'TV-14'}
# {'titre': 'House of the Witch', 'Directeur': 'Alex Merkin', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Ginny Weds Sunny', 'Directeur': 'Puneet Khanna', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'My Step Dad: The Hippie', 'Directeur': 'Meltem Bozoflu', 'Pays': 'Turkey, South Korea', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'Super Monsters: Dia de los Monsters', 'Directeur': '', 'Pays': 'Canada', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'The Forty-Year-Old Version', 'Directeur': 'Radha Blank', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Bigflo & Oli: Hip Hop Frenzy', 'Directeur': 'Bigflo & Oli, Jérémie Levypon', 'Pays': 'France', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Palermo Hollywood', 'Directeur': 'Eduardo Pinto', 'Pays': 'Argentina', 'Année de sortie': '2004', 'Note': 'TV-MA'}
# {'titre': 'Hubie Halloween', 'Directeur': 'Steve Brill', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'PG-13'}
# {'titre': "American Pie 9: Girls' Rules", 'Directeur': 'Mike Elliott', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Dolly Parton: Here I Am', 'Directeur': 'Francis Whately', 'Pays': 'United Kingdom', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'StarBeam: Halloween Hero', 'Directeur': 'Jon Izen', 'Pays': 'Canada', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Walk Away from Love', 'Directeur': 'Christopher Nolen', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'TV-14'}
# {'titre': 'David Attenborough: A Life on Our Planet', 'Directeur': 'Alastair Fothergill, Jonnie Hughes, Keith Scholey', 'Pays': 'United States, United Kingdom', 'Année de sortie': '2020', 'Note': 'PG'}
# {'titre': "Best Wishes, Warmest Regards: A Schitt's Creek Farewell", 'Directeur': 'Amy Segal', 'Pays': 'Canada', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Good Game: The Beginning', 'Directeur': 'Umut Aral', 'Pays': 'Turkey', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'A Chaster Marriage', 'Directeur': 'Umut Kirca', 'Pays': 'Turkey', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'A Go! Go! Cory Carson Halloween', 'Directeur': 'Alex Woo, Stanley Moore', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Òlòtūré', 'Directeur': 'Kenneth Gyang', 'Pays': 'Nigeria', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Serious Men', 'Directeur': 'Sudhir Mishra', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Binding', 'Directeur': 'Domenico de Feudis', 'Pays': 'Italy', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Turkish Dance School', 'Directeur': 'Burak Aksak', 'Pays': 'Turkey', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Vampires vs. the Bronx', 'Directeur': 'Oz Rodriguez', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'PG-13'}
# {'titre': "You've Got This", 'Directeur': 'Salvador Espinosa', 'Pays': 'Mexico', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'All Because of You', 'Directeur': 'Adrian Teh', 'Pays': 'Malaysia', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'An Ordinary Man', 'Directeur': 'Brad Silberling', 'Pays': 'Serbia, United States', 'Année de sortie': '2017', 'Note': 'R'}
# {'titre': 'Carlos Almaraz: Playing with Fire', 'Directeur': 'Elsa Flores Almaraz, Richard J Montoya', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'Cold Harbour', 'Directeur': 'Carey McKenzie', 'Pays': 'South Africa', 'Année de sortie': '2013', 'Note': 'TV-MA'}
# {'titre': 'Free State of Jones', 'Directeur': 'Gary Ross', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'Human Nature', 'Directeur': 'Adam Bolt', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'Hunt for the Wilderpeople', 'Directeur': 'Taika Waititi', 'Pays': 'New Zealand', 'Année de sortie': '2016', 'Note': 'PG-13'}
# {'titre': "I'm Leaving Now", 'Directeur': 'Lindsey Cordero, Armando Croda', 'Pays': 'United States, Mexico', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Rize', 'Directeur': 'David LaChapelle', 'Pays': 'United States, United Kingdom', 'Année de sortie': '2005', 'Note': 'PG-13'}
# {'titre': 'The American Game', 'Directeur': 'Mostafa Abu Seif', 'Pays': '', 'Année de sortie': '2019', 'Note': 'TV-PG'}
# {'titre': 'The Book of Sun', 'Directeur': 'Faris Godus', 'Pays': 'Saudi Arabia', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'The Outpost', 'Directeur': 'Rod Lurie', 'Pays': 'United States, Bulgaria', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'We Have Always Lived in the Castle', 'Directeur': 'Stacie Passon', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'American Murder: The Family Next Door', 'Directeur': 'Jenny Popplewell', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Baxu and the Giants', 'Directeur': 'Florian Schott', 'Pays': 'Namibia', 'Année de sortie': '2019', 'Note': 'TV-PG'}
# {'titre': 'Poacher', 'Directeur': 'Tom Whitworth', 'Pays': 'United Kingdom, Kenya', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'The Boys in the Band', 'Directeur': 'Joe Mantello', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'The Boys in the Band: Something Personal', 'Directeur': '', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Bully', 'Directeur': 'Lee Hirsch', 'Pays': 'United States', 'Année de sortie': '2012', 'Note': 'PG-13'}
# {'titre': 'Michelle Buteau: Welcome to Buteaupia', 'Directeur': 'Page Hurwitz', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Welcome to Sudden Death', 'Directeur': 'Dallas Jackson', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Amandla! A Revolution in Four Part Harmony', 'Directeur': 'Lee Hirsch', 'Pays': 'South Africa, United States', 'Année de sortie': '2002', 'Note': 'PG-13'}
# {'titre': 'Ankhon Dekhi', 'Directeur': 'Rajat Kapoor', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-PG'}
# {'titre': 'Dedh Ishqiya', 'Directeur': 'Abhishek Chaubey', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'Golmaal Returns', 'Directeur': 'Rohit Shetty', 'Pays': 'India', 'Année de sortie': '2008', 'Note': 'TV-MA'}
# {'titre': 'Ishq Vishk', 'Directeur': 'Ken Ghosh', 'Pays': 'India', 'Année de sortie': '2003', 'Note': 'TV-PG'}
# {'titre': 'Ishqiya', 'Directeur': 'Abhishek Chaubey', 'Pays': 'India', 'Année de sortie': '2009', 'Note': 'TV-14'}
# {'titre': 'Jab We Met', 'Directeur': 'Imtiaz Ali', 'Pays': 'India', 'Année de sortie': '2007', 'Note': 'TV-14'}
# {'titre': 'Mann', 'Directeur': 'Indra Kumar', 'Pays': 'India', 'Année de sortie': '1999', 'Note': 'TV-14'}
# {'titre': 'Manorama Six Feet Under', 'Directeur': 'Navdeep Singh', 'Pays': 'India', 'Année de sortie': '2007', 'Note': 'TV-14'}
# {'titre': 'Welcome', 'Directeur': 'Anees Bazmee', 'Pays': 'India', 'Année de sortie': '2007', 'Note': 'TV-PG'}
# {'titre': 'Time Out', 'Directeur': 'Rikhil Bahadur', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-14'}
# {'titre': "My Mother's Wound", 'Directeur': 'Ozan Açıktan', 'Pays': '', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'Zulu Man in Japan', 'Directeur': '', 'Pays': '', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Real Steel', 'Directeur': 'Shawn Levy', 'Pays': 'United States, India', 'Année de sortie': '2011', 'Note': 'PG-13'}
# {'titre': 'Enola Holmes', 'Directeur': 'Harry Bradbeer', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'PG-13'}
# {'titre': 'Kiss the Ground', 'Directeur': 'Joshua Tickell, Rebecca Harrell Tickell', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-G'}
# {'titre': 'A Love Song for Latasha', 'Directeur': 'Sophia Nahli Allison', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'DTC Yukemuri Junjo Hen From High & Low', 'Directeur': 'Norihisa Hiranuma', 'Pays': 'Japan', 'Année de sortie': '2018', 'Note': 'TV-PG'}
# {'titre': 'High & Low The Movie', 'Directeur': 'Shigeaki Kubo', 'Pays': 'Japan', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'High & Low The Movie 2 / End of Sky', 'Directeur': 'Shigeaki Kubo, Tsuyoshi Nakakuki', 'Pays': 'Japan', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'High & Low The Movie 3 / Final Mission', 'Directeur': 'Shigeaki Kubo, Tsuyoshi Nakakuki', 'Pays': 'Japan', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'High & Low The Red Rain', 'Directeur': 'Yudai Yamaguchi', 'Pays': 'Japan', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'High & Low The Worst', 'Directeur': 'Shigeaki Kubo', 'Pays': '', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Road To High & Low', 'Directeur': 'Shigeaki Kubo', 'Pays': 'Japan', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'The Blue Elephant 2', 'Directeur': 'Marwan Hamed', 'Pays': 'Egypt', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Bhaji In Problem', 'Directeur': 'Smeep Kang', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-14'}
# {'titre': 'Black', 'Directeur': 'Raja Chanda', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-14'}
# {'titre': 'Saheb Biwi Aur Gangster Returns', 'Directeur': 'Tigmanshu Dhulia', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-MA'}
# {'titre': 'Santa Banta Pvt Ltd', 'Directeur': 'Akashdeep', 'Pays': 'India', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'The Royal Bengal Tiger', 'Directeur': 'Rajesh Ganguly', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-MA'}
# {'titre': 'Dolly Kitty Aur Woh Chamakte Sitare', 'Directeur': 'Alankrita Shrivastava', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Whipped', 'Directeur': 'Chandra Liow', 'Pays': 'Indonesia', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Anaamika', 'Directeur': 'Sekhar Kammula', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'GIMS: On the Record', 'Directeur': 'Florent Bodin', 'Pays': 'France', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': "Horrid Henry's Gross Day Out", 'Directeur': 'Gary Andrews', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Nee Enge En Anbe', 'Directeur': 'Sekhar Kammula', 'Pays': '', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'Residue', 'Directeur': 'Merawi Gerima', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Dr Jason Leong Hashtag Blessed', 'Directeur': 'Kubhaer T. Jethwani', 'Pays': '', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'The Devil All The Time', 'Directeur': 'Antonio Campos', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'The Paramedic', 'Directeur': 'Carles Torras', 'Pays': 'Spain', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Take', 'Directeur': 'James Watkins', 'Pays': 'United Kingdom, France, United States, Belgium, Luxembourg, China, Germany', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'Hope Frozen: A Quest to Live Twice', 'Directeur': 'Pailin Wedel', 'Pays': 'Thailand, United States', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Michael McIntyre: Showman', 'Directeur': 'Chris Howe', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Raising Victor Vargas', 'Directeur': 'Peter Sollett', 'Pays': 'France, United States', 'Année de sortie': '2002', 'Note': 'R'}
# {'titre': 'The Smurfs 2', 'Directeur': 'Raja Gosnell', 'Pays': 'United States, France, Canada, Belgium', 'Année de sortie': '2013', 'Note': 'PG'}
# {'titre': 'Wish Upon a Unicorn', 'Directeur': 'Steve Bencich', 'Pays': '', 'Année de sortie': '2020', 'Note': 'PG'}
# {'titre': 'Lara and the Beat', 'Directeur': 'Tosin Coker', 'Pays': 'Nigeria', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'Dad Wanted', 'Directeur': 'Javier Colinas', 'Pays': 'Mexico', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'How to Train Your Dragon 2', 'Directeur': 'Dean DeBlois', 'Pays': 'United States', 'Année de sortie': '2014', 'Note': 'PG'}
# {'titre': 'Pets United', 'Directeur': 'Reinhard Klooss', 'Pays': 'Germany, China, United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-Y7'}
# {'titre': 'Wonho Chung: Live in New York', 'Directeur': 'Shaun Mir', 'Pays': '', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'Aapla Manus', 'Directeur': 'Satish Rajwade', 'Pays': 'India', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'Ani... Dr. Kashinath Ghanekar', 'Directeur': 'Abhijeet Deshpande', 'Pays': 'India', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'Bhai: Vyakti Ki Valli - Poorvardha', 'Directeur': 'Mahesh Manjrekar', 'Pays': 'India', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'Bhai: Vyakti Ki Valli - Uttarardh', 'Directeur': 'Mahesh Manjrekar', 'Pays': 'India', 'Année de sortie': '2019', 'Note': 'TV-PG'}
# {'titre': 'Cycle', 'Directeur': 'Prakash Kunte', 'Pays': 'India', 'Année de sortie': '2018', 'Note': 'TV-PG'}
# {'titre': 'Dhh', 'Directeur': 'Manish Saini', 'Pays': 'India', 'Année de sortie': '2017', 'Note': 'TV-G'}
# {'titre': 'Kaagar', 'Directeur': 'Makarand Mane', 'Pays': 'India', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Night of Knots', 'Directeur': 'Hakan Algül', 'Pays': 'Turkey', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'PhotoCopy', 'Directeur': 'Vijay Maurya', 'Pays': 'India', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Poshter Girl', 'Directeur': 'Sameer Patil', 'Pays': 'India', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Satria Heroes: Revenge of the Darkness', 'Directeur': 'Kenzo Maihara, Amandha Wyanto', 'Pays': 'Indonesia', 'Année de sortie': '2017', 'Note': 'TV-G'}
# {'titre': 'Son Of Adam', 'Directeur': 'Ahmed Nader Galal', 'Pays': 'Egypt', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'The Babysitter: Killer Queen', 'Directeur': 'McG', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Cargo', 'Directeur': 'Arati Kadav', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Cuties', 'Directeur': 'Maïmouna Doucouré', 'Pays': 'France', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'So Much Love to Give', 'Directeur': 'Marcos Carnevale', 'Pays': 'Argentina', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'The Social Dilemma', 'Directeur': 'Jeff Orlowski', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'PG-13'}
# {'titre': '#Alive', 'Directeur': 'Cho Il', 'Pays': 'South Korea', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'My Octopus Teacher', 'Directeur': 'Pippa Ehrlich, James Reed', 'Pays': 'South Africa', 'Année de sortie': '2020', 'Note': 'TV-G'}
# {'titre': 'Toll Booth', 'Directeur': 'Tolga Karaçelik', 'Pays': 'Turkey', 'Année de sortie': '2010', 'Note': 'TV-MA'}
# {'titre': 'Waiting for "Superman"', 'Directeur': 'Davis Guggenheim', 'Pays': 'United States', 'Année de sortie': '2010', 'Note': 'PG'}
# {'titre': 'Villain', 'Directeur': 'Philip Barantini', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': "I'm Thinking of Ending Things", 'Directeur': 'Charlie Kaufman', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Kandasamys: The Wedding', 'Directeur': 'Jayan Moodley', 'Pays': 'South Africa', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'The Lost Okoroshi', 'Directeur': 'Abba T. Makama', 'Pays': 'Nigeria', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': "You're My Boss", 'Directeur': 'Antoinette Jadaone', 'Pays': 'Philippines', 'Année de sortie': '2015', 'Note': 'TV-14'}
# {'titre': 'Afonso Padilha: Classless', 'Directeur': 'Junior Carelli, Rudge Campos', 'Pays': 'Brazil', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Ave Maryam', 'Directeur': 'Ertanto Robby Soediskam', 'Pays': 'Indonesia', 'Année de sortie': '2018', 'Note': 'TV-PG'}
# {'titre': 'Love, Guaranteed', 'Directeur': 'Mark Steven Johnson', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': "Freaks – You're One of Us", 'Directeur': 'Felix Binder', 'Pays': 'Germany', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Hotel for Dogs', 'Directeur': 'Thor Freudenthal', 'Pays': 'Germany, United States', 'Année de sortie': '2009', 'Note': 'PG'}
# {'titre': 'Sky Tour: The Movie', 'Directeur': 'Nguyen Thanh Tung', 'Pays': 'Vietnam', 'Année de sortie': '2020', 'Note': 'TV-G'}
# {'titre': 'Adrift', 'Directeur': 'Baltasar Kormákur', 'Pays': 'Hong Kong, Iceland, United States', 'Année de sortie': '2018', 'Note': 'PG-13'}
# {'titre': 'Always Be My Maybe', 'Directeur': 'Dan Villegas', 'Pays': 'Philippines', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Barbie Princess Adventure', 'Directeur': 'Conrad Helten', 'Pays': 'Netherlands', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Children of the Sea', 'Directeur': 'Ayumu Watanabe', 'Pays': 'Japan, United States', 'Année de sortie': '2019', 'Note': 'TV-PG'}
# {'titre': 'Fate/Grand Order -First Order-', 'Directeur': 'Hitoshi Namba', 'Pays': 'Japan', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Puss in Boots', 'Directeur': 'Chris Miller', 'Pays': 'United States', 'Année de sortie': '2011', 'Note': 'PG'}
# {'titre': 'Sex Drive', 'Directeur': 'Sean Anders', 'Pays': 'United States', 'Année de sortie': '2008', 'Note': 'R'}
# {'titre': 'Soldier', 'Directeur': 'Abbas Mustan', 'Pays': 'India', 'Année de sortie': '1998', 'Note': 'TV-14'}
# {'titre': 'Take the Ball, Pass the Ball', 'Directeur': 'Duncan McMath', 'Pays': 'Spain', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'The Boss Baby: Get That Baby!', 'Directeur': 'Dan Forgione, Pete Jacobs, Matt Whitlock', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-Y7'}
# {'titre': 'The Match', 'Directeur': 'Francesco Carnesecchi', 'Pays': 'Italy', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Smurfs', 'Directeur': 'Raja Gosnell', 'Pays': 'United States, Belgium, Canada, France', 'Année de sortie': '2011', 'Note': 'PG'}
# {'titre': 'True: Friendship Day', 'Directeur': 'Mark Thornton, Todd Kauffman', 'Pays': 'Canada', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Maniyarayile Ashokan', 'Directeur': 'Shamzu Zayba', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'The Debt Collector 2', 'Directeur': 'Jesse V. Johnson', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'All Together Now', 'Directeur': 'Brett Haley', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'PG'}
# {'titre': 'Santana', 'Directeur': 'Chris Roland, Maradona Dias Dos Santos', 'Pays': 'South Africa, Angola', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Unknown Origins', 'Directeur': 'David Galán Galindo', 'Pays': 'Spain', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Edge of Seventeen', 'Directeur': 'David Moreton', 'Pays': 'United States', 'Année de sortie': '1998', 'Note': 'TV-MA'}
# {'titre': 'The Bridge Curse', 'Directeur': 'Lester Hsi', 'Pays': 'Taiwan', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Young Messiah', 'Directeur': 'Cyrus Nowrasteh', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'PG-13'}
# {'titre': 'Lingua Franca', 'Directeur': 'Isabel Sandoval', 'Pays': 'United States, Philippines', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Making The Witcher', 'Directeur': 'Nathan Wiley', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Rising Phoenix', 'Directeur': '', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'PG-13'}
# {'titre': 'Septembers of Shiraz', 'Directeur': 'Wayne Blair', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'PG-13'}
# {'titre': "Class of '83", 'Directeur': 'Atul Sabharwal', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Dark Forces', 'Directeur': 'Bernardo Arellano', 'Pays': 'Mexico', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Sleepover', 'Directeur': 'Trish Sie', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'John Was Trying to Contact Aliens', 'Directeur': '', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Scarecrow', 'Directeur': 'Khaled Marei', 'Pays': 'Egypt', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'The Crimes That Bind', 'Directeur': 'Sebastián Schindel', 'Pays': 'Argentina', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Little Singham: Kaal Ka Badla', 'Directeur': 'Prakash Satam', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-Y7'}
# {'titre': 'Drunk Parents', 'Directeur': 'Fred Wolf', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'R'}
# {'titre': 'Meet the In-Laws', 'Directeur': 'Niyi Akinmolayan', 'Pays': 'Nigeria', 'Année de sortie': '2017', 'Note': 'TV-PG'}
# {'titre': 'Crazy Awesome Teachers', 'Directeur': 'Sammaria Sari Simanjuntak', 'Pays': 'Indonesia', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Islands of Faith', 'Directeur': 'Chairun Nissa', 'Pays': 'Indonesia', 'Année de sortie': '2018', 'Note': 'TV-PG'}
# {'titre': 'Les Misérables', 'Directeur': 'Tom Hooper', 'Pays': 'United Kingdom, United States', 'Année de sortie': '2012', 'Note': 'PG-13'}
# {'titre': 'Seventh Son', 'Directeur': 'Sergei Bodrov', 'Pays': 'United States, United Kingdom, Canada, China', 'Année de sortie': '2014', 'Note': 'PG-13'}
# {'titre': "What's Your Raashee?", 'Directeur': 'Ashutosh Gowariker', 'Pays': 'India', 'Année de sortie': '2009', 'Note': 'TV-PG'}
# {'titre': "Beyond the Boundary: ICC Women's T20 World Cup Australia 2020", 'Directeur': 'Anna Stone', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-G'}
# {'titre': 'Fearless', 'Directeur': 'Cory Edwards', 'Pays': 'Canada', 'Année de sortie': '2020', 'Note': 'TV-Y7'}
# {'titre': 'Nigerian Prince', 'Directeur': 'Faraday Okoro', 'Pays': 'United States, Nigeria', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'Octonauts & the Caves of Sac Actun', 'Directeur': 'Blair Simmons', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Project Power', 'Directeur': 'Henry Joost, Ariel Schulman', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'An Easy Girl', 'Directeur': 'Rebecca Zlotowski', 'Pays': 'France', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Christine', 'Directeur': 'Antonio Campos', 'Pays': 'United Kingdom, United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'Simon Killer', 'Directeur': 'Antonio Campos', 'Pays': 'United States, France', 'Année de sortie': '2012', 'Note': 'TV-MA'}
# {'titre': 'Gunjan Saxena: The Kargil Girl', 'Directeur': 'Sharan Sharma', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Mr. Peabody & Sherman', 'Directeur': 'Rob Minkoff', 'Pays': 'United States', 'Année de sortie': '2014', 'Note': 'PG'}
# {'titre': 'Rob Schneider: Asian Momma, Mexican Kids', 'Directeur': 'Tyler Spindel', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Lost Husband', 'Directeur': 'Vicky Wight', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'PG-13'}
# {'titre': 'Diamonds in the Sky', 'Directeur': 'Kunle Afolayan', 'Pays': '', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'We Summon the Darkness', 'Directeur': 'Marc Meyers', 'Pays': 'United States, Canada, United Kingdom', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Berlin, Berlin: Lolle on the Run', 'Directeur': 'Franziska Meyer Price', 'Pays': 'Germany', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Stars in the Sky: A Hunting Story', 'Directeur': 'Steven Rinella', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'The Magic School Bus Rides Again Kids In Space', 'Directeur': 'Richard Weston', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Work It', 'Directeur': 'Laura Terruso', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Nasha Natasha', 'Directeur': 'Martín Sastre', 'Pays': 'Uruguay', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Anelka: Misunderstood', 'Directeur': 'Franck Nataf', 'Pays': 'France', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Sin City', 'Directeur': 'Pascal Amanfo', 'Pays': '', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'A Go! Go! Cory Carson Summer Camp', 'Directeur': 'Stanley Moore, Alex Woo', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Malibu Rescue: The Next Wave', 'Directeur': 'Savage Steve Holland', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-G'}
# {'titre': 'Sam Jay: 3 In The Morning', 'Directeur': 'Kristian Mercado', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Almost Love', 'Directeur': 'Mike Doyle', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Killing Hasselhoff', 'Directeur': 'Darren Grant', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'R'}
# {'titre': 'Rogue Warfare: The Hunt', 'Directeur': 'Mike Gunther', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Super Monsters: The New Class', 'Directeur': 'Steve Ball', 'Pays': 'Canada', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'The Ottoman Lieutenant', 'Directeur': 'Joseph Ruben', 'Pays': 'Turkey, United States', 'Année de sortie': '2017', 'Note': 'R'}
# {'titre': 'Tumi or not Tumi', 'Directeur': 'Mfanelo Ngoma', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'What Keeps You Alive', 'Directeur': 'Colin Minihan', 'Pays': 'Canada', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'Latte and the Magic Waterstone', 'Directeur': 'Regina Welker, Nina Wels', 'Pays': 'Germany', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Raat Akeli Hai', 'Directeur': 'Honey Trehan', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Seriously Single', 'Directeur': 'Katleho Ramaphakela, Rethabile Ramaphakela', 'Pays': 'South Africa', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Sugar High', 'Directeur': 'Ariel Boles', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-G'}
# {'titre': 'Retablo', 'Directeur': 'Álvaro Delgado-Aparicio L.', 'Pays': 'Peru, Germany, Norway', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Uma Maheswara Ugra Roopasya', 'Directeur': 'Venkatesh Maha', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': "It's Her Day", 'Directeur': 'Aniedi Anwah', 'Pays': 'Nigeria', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'Redemption', 'Directeur': 'Mickey Fonseca', 'Pays': 'Mozambique', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Shine Your Eyes', 'Directeur': 'Matias Mariani', 'Pays': 'Brazil, France', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Hater', 'Directeur': 'Jan Komasa', 'Pays': 'Poland', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Speed Cubers', 'Directeur': 'Sue Kim', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-PG'}
# {'titre': 'Tread', 'Directeur': 'Paul Solet', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Banana Split', 'Directeur': 'Ben Kasulke', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Door Ke Darshan', 'Directeur': 'Gagan Puri', 'Pays': 'India', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Double World', 'Directeur': 'Teddy Chan', 'Pays': 'China', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'Project Marathwada', 'Directeur': 'Bhavin Wadia', 'Pays': 'India', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'Animal Crackers', 'Directeur': 'Tony Bancroft, Scott Christian Sava', 'Pays': 'China, Spain, South Korea, United States', 'Année de sortie': '2020', 'Note': 'TV-Y7'}
# {'titre': 'Dragons: Rescue Riders: Secrets of the Songwing', 'Directeur': 'Greg Rankin, TJ Sullivan', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-Y'}
# {'titre': 'Nimbe', 'Directeur': 'Tope Alake', 'Pays': 'Nigeria', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Offering to the Storm', 'Directeur': 'Fernando González Molina', 'Pays': 'Spain, Germany', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Romance Doll', 'Directeur': 'Yuki Tanada', 'Pays': 'Japan', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'The Kissing Booth 2', 'Directeur': 'Vince Marcello', 'Pays': 'United Kingdom, United States', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'The Larva Island Movie', 'Directeur': 'Ahn Byoung-wook', 'Pays': 'South Korea', 'Année de sortie': '2020', 'Note': 'TV-Y7'}
# {'titre': 'The Letter Reader', 'Directeur': 'Sibusiso Khuzwayo', 'Pays': 'South Africa', 'Année de sortie': '2019', 'Note': 'TV-PG'}
# {'titre': 'The Remix: Hip Hop X Fashion', 'Directeur': 'Lisa Cortés, Farah X', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Ip Man 4: The Finale', 'Directeur': 'Wilson Yip', 'Pays': 'Hong Kong, China', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': "Jack Whitehall: I'm Only Joking", 'Directeur': 'Dave Skinner, Freddie Waters', 'Pays': 'United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Funan', 'Directeur': 'Denis Do', 'Pays': 'France, Belgium, Luxembourg, Cambodia,', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'Father Soldier Son', 'Directeur': 'Leslye Davis, Catrin Einhorn', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'The Millions', 'Directeur': 'Toka McBaror, Tunde Apalowo', 'Pays': 'Nigeria', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Fatal Affair', 'Directeur': 'Peter Sullivan', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'MILF', 'Directeur': 'Axelle Laffont', 'Pays': 'France, Belgium', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'Cold Feet', 'Directeur': 'Moses Inwang', 'Pays': 'Nigeria', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'Little Singham: Legend of Dugabakka', 'Directeur': '', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-Y7'}
# {'titre': 'Sylvia', 'Directeur': 'Daniel Oriahi', 'Pays': 'Nigeria', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'The Players', 'Directeur': 'Stefano Mordini', 'Pays': 'Italy', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Urzila Carlson: Overqualified Loser', 'Directeur': 'Hayden Guppy', 'Pays': 'Australia', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'We Are One', 'Directeur': 'Stéphane de Freitas', 'Pays': 'France', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Hole in the Wall', 'Directeur': 'André Odendaal, Johan Vorster', 'Pays': 'South Africa', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': "Mama's Boy", 'Directeur': 'Amro Salah', 'Pays': 'Egypt', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'The Claudia Kishi Club', 'Directeur': 'Sue Ding', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'The Old Guard', 'Directeur': 'Gina Prince-Bythewood', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'R'}
# {'titre': 'Your Excellency', 'Directeur': 'Funke Akindele', 'Pays': '', 'Année de sortie': '2019', 'Note': 'TV-G'}
# {'titre': 'Born Racer', 'Directeur': 'Bryn Evans', 'Pays': 'New Zealand', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'Mucho Mucho Amor: The Legend of Walter Mercado', 'Directeur': 'Cristina Costantini, Kareem Tabsch', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-14'}
# {'titre': 'The Long Dumb Road', 'Directeur': 'Hannah Fidell', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': "Dr. Seuss' The Lorax", 'Directeur': 'Chris Renaud, Kyle Balda', 'Pays': 'United States, France', 'Année de sortie': '2012', 'Note': 'PG'}
# {'titre': 'Jim Jefferies: Intolerant', 'Directeur': 'Scott Zabielski', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'A Kid from Coney Island', 'Directeur': 'Coodie, Chike', 'Pays': 'United States, China', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'PNL - Dans la légende tour', 'Directeur': 'QLF', 'Pays': '', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Aiyyaa', 'Directeur': 'Sachin Kundalkar', 'Pays': 'India', 'Année de sortie': '2012', 'Note': 'TV-14'}
# {'titre': 'Bbuddah Hoga Terra Baap', 'Directeur': 'Puri Jagannadh', 'Pays': 'India', 'Année de sortie': '2011', 'Note': 'TV-14'}
# {'titre': 'Blood Money', 'Directeur': 'Vishal Mahadkar', 'Pays': 'India', 'Année de sortie': '2012', 'Note': 'TV-14'}
# {'titre': 'Bombay Talkies', 'Directeur': 'Anurag Kashyap, Dibakar Banerjee, Karan Johar, Zoya Akhtar', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-MA'}
# {'titre': 'Boss', 'Directeur': "Anthony D'Souza", 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-14'}
# {'titre': 'Budhia Singh: Born to Run', 'Directeur': 'Soumendra Padhi', 'Pays': 'India', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'Chashme Baddoor', 'Directeur': 'David Dhawan', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-14'}
# {'titre': 'Dharam Sankat Mein', 'Directeur': 'Fuwad Khan', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-PG'}
# {'titre': 'Drishyam', 'Directeur': 'Nishikant Kamat', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-14'}
# {'titre': 'Gabbar Is Back', 'Directeur': 'Krish', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-14'}
# {'titre': 'Gollu Aur Pappu', 'Directeur': 'Kabir Sadanand', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'Inkaar', 'Directeur': 'Sudhir Mishra', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-MA'}
# {'titre': 'Madras Café', 'Directeur': 'Shoojit Sircar', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-14'}
# {'titre': 'Mary Kom', 'Directeur': 'Omung Kumar', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-PG'}
# {'titre': 'Michael', 'Directeur': 'Ribhu Dasgupta', 'Pays': 'India', 'Année de sortie': '2011', 'Note': 'TV-MA'}
# {'titre': 'Mumbai Delhi Mumbai', 'Directeur': 'Satish Rajwade', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-MA'}
# {'titre': 'Oh My God', 'Directeur': 'Umesh Shukla', 'Pays': 'India', 'Année de sortie': '2012', 'Note': 'TV-PG'}
# {'titre': 'One by Two', 'Directeur': 'Devika Bhagat', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'Only', 'Directeur': 'Takashi Doscher', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Penalty', 'Directeur': 'Shubham Singh', 'Pays': 'India', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'Players', 'Directeur': 'Abbas Alibhai Burmawalla, Mastan Alibhai Burmawalla', 'Pays': 'India', 'Année de sortie': '2012', 'Note': 'TV-14'}
# {'titre': 'Pyaar Ka Punchnama 2', 'Directeur': 'Luv Ranjan', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-MA'}
# {'titre': 'Queen', 'Directeur': 'Vikas Bahl', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-MA'}
# {'titre': 'Shaitan', 'Directeur': 'Bejoy Nambiar', 'Pays': 'India', 'Année de sortie': '2011', 'Note': 'TV-MA'}
# {'titre': 'Special 26', 'Directeur': 'Neeraj Pandey', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-PG'}
# {'titre': 'Tanu Weds Manu', 'Directeur': 'Aanand Rai', 'Pays': 'India', 'Année de sortie': '2011', 'Note': 'TV-14'}
# {'titre': 'What the Fish', 'Directeur': 'Gurmmeet Singh', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-14'}
# {'titre': 'Desperados', 'Directeur': 'LP', 'Pays': 'United States', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'Hunter in the Blue Side of Manchester', 'Directeur': 'Rako Prijanto', 'Pays': 'Indonesia, United Kingdom', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# {'titre': 'I Am Not Your Negro', 'Directeur': 'Raoul Peck', 'Pays': 'Switzerland, France, Belgium, United States', 'Année de sortie': '2017', 'Note': 'PG-13'}
# {'titre': 'The Perfect Picture: Ten Years Later', 'Directeur': 'Shirley Frimpong-Manso', 'Pays': 'Ghana', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'Thiago Ventura: POKAS', 'Directeur': 'Fabio Ock, Joana Mazzucchelli', 'Pays': 'Brazil', 'Année de sortie': '2020', 'Note': 'TV-MA'}
# ...
# {'titre': 'Under The Skin', 'Directeur': 'Jonathan Glazer', 'Pays': 'Switzerland, United Kingdom, United States', 'Année de sortie': '2013', 'Note': 'R'}
# {'titre': 'Undercover Grandpa', 'Directeur': 'Erik Canuel', 'Pays': 'Canada', 'Année de sortie': '2016', 'Note': 'PG-13'}
# {'titre': 'Undercover: How to Operate Behind Enemy Lines', 'Directeur': 'John Ford', 'Pays': 'United States', 'Année de sortie': '1943', 'Note': 'TV-PG'}
# {'titre': 'Unfinished Song', 'Directeur': 'Paul Andrew Williams', 'Pays': 'United Kingdom, Germany', 'Année de sortie': '2012', 'Note': 'PG-13'}
# {'titre': 'Union Leader', 'Directeur': 'Sanjay Patel', 'Pays': 'Canada, India', 'Année de sortie': '2017', 'Note': 'TV-14'}
# {'titre': 'Unruly Friends', 'Directeur': 'Sherif Mandour', 'Pays': 'Egypt', 'Année de sortie': '2011', 'Note': 'TV-14'}
# {'titre': 'Up in the Air', 'Directeur': 'Jason Reitman', 'Pays': 'United States', 'Année de sortie': '2009', 'Note': 'R'}
# {'titre': 'Urvi', 'Directeur': 'Pradeep Verma', 'Pays': 'India', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Used Goods', 'Directeur': 'Mohamed Hamdy', 'Pays': 'Egypt', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'USS Indianapolis: Men of Courage', 'Directeur': 'Mario Van Peebles', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'V for Vendetta', 'Directeur': 'James McTeigue', 'Pays': 'United States, United Kingdom, Germany', 'Année de sortie': '2005', 'Note': 'R'}
# {'titre': 'Vantage Point', 'Directeur': 'Pete Travis', 'Pays': 'United States', 'Année de sortie': '2008', 'Note': 'PG-13'}
# {'titre': 'Veerappan', 'Directeur': 'Ram Gopal Varma', 'Pays': 'India', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Veerey Ki Wedding', 'Directeur': 'Ashu Trikha', 'Pays': 'India', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'Vegas Baby', 'Directeur': 'Amanda Micheli', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': "Viceroy's House", 'Directeur': 'Gurinder Chadha', 'Pays': 'United Kingdom, India, Sweden', 'Année de sortie': '2017', 'Note': 'NR'}
# {'titre': 'Victor', 'Directeur': 'Brandon Dickerson', 'Pays': 'United States', 'Année de sortie': '2015', 'Note': 'PG-13'}
# {'titre': 'Viking Destiny', 'Directeur': 'David L.G. Hughes', 'Pays': 'United Kingdom, Belgium', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'Vikings Unearthed', 'Directeur': 'Harvey Lilley', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'TV-PG'}
# {'titre': 'Vincent N Roxxy', 'Directeur': 'Gary Michael Schultz', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'Viswasapoorvam Mansoor', 'Directeur': 'P.T. Kunju Muhammad', 'Pays': 'India', 'Année de sortie': '2017', 'Note': 'TV-14'}
# {'titre': 'Vitti Dandu', 'Directeur': 'Ganesh Kadam', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'Vizontele Tuuba', 'Directeur': 'Yılmaz Erdoğan', 'Pays': 'Turkey', 'Année de sortie': '2004', 'Note': 'NR'}
# {'titre': 'Vodka Diaries', 'Directeur': 'Kushal Srivastava', 'Pays': 'India', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'VS.', 'Directeur': 'Ed Lilly', 'Pays': 'United Kingdom', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'Waar', 'Directeur': 'Bilal Lashari', 'Pays': 'Pakistan', 'Année de sortie': '2013', 'Note': 'TV-MA'}
# {'titre': 'Waarrior Savitri', 'Directeur': 'Param Gill', 'Pays': 'India', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Waiting', 'Directeur': 'Anu Menon', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-MA'}
# {'titre': 'Waiting...', 'Directeur': 'Rob McKittrick', 'Pays': 'United States', 'Année de sortie': '2005', 'Note': 'R'}
# {'titre': 'Wakefield', 'Directeur': 'Robin Swicord', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'Walk with Me', 'Directeur': 'Marc Francis, Max Pugh', 'Pays': 'United Kingdom', 'Année de sortie': '2017', 'Note': 'TV-PG'}
# {'titre': 'Walking Out', 'Directeur': 'Alex Smith, Andrew J. Smith', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'PG-13'}
# {'titre': 'War', 'Directeur': 'Philip G. Atwell', 'Pays': 'United States, Canada', 'Année de sortie': '2007', 'Note': 'R'}
# {'titre': 'War Chhod Na Yaar', 'Directeur': 'Faraz Haider', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-14'}
# {'titre': 'War Horse', 'Directeur': 'Steven Spielberg', 'Pays': 'United States, India', 'Année de sortie': '2011', 'Note': 'PG-13'}
# {'titre': 'War on Everyone', 'Directeur': 'John Michael McDonagh', 'Pays': 'United Kingdom', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'Warda', 'Directeur': 'Hadi El Bagoury', 'Pays': 'Egypt', 'Année de sortie': '2014', 'Note': 'TV-14'}
# {'titre': 'Warehoused', 'Directeur': 'Jack Zagha Kababie', 'Pays': 'Mexico', 'Année de sortie': '2015', 'Note': 'TV-14'}
# {'titre': 'Water & Power: A California Heist', 'Directeur': 'Marina Zenovich', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'PG'}
# {'titre': 'Waterschool', 'Directeur': 'Tiffanie Hsu', 'Pays': 'United States, Brazil, India, Uganda, China', 'Année de sortie': '2018', 'Note': 'TV-G'}
# {'titre': 'We Are Your Friends', 'Directeur': 'Max Joseph', 'Pays': 'United Kingdom, France, United States', 'Année de sortie': '2015', 'Note': 'R'}
# {'titre': 'We Belong Together', 'Directeur': 'Chris Stokes', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'We Need to Talk', 'Directeur': 'David Serrano', 'Pays': 'Spain', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'We the Animals', 'Directeur': 'Jeremiah Zagar', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'R'}
# {'titre': 'We, the Marines', 'Directeur': 'Greg MacGillivray', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'TV-PG'}
# {'titre': "We're No Animals", 'Directeur': 'Alejandro Agresti', 'Pays': 'United States, Argentina', 'Année de sortie': '2015', 'Note': 'TV-MA'}
# {'titre': 'Weather forecast', 'Directeur': 'Antoni Krauze', 'Pays': 'Poland', 'Année de sortie': '1983', 'Note': 'TV-MA'}
# {'titre': 'Weeds on Fire', 'Directeur': 'Chi Fat Chan', 'Pays': 'Hong Kong', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'Welcome 2 Karachi', 'Directeur': 'Ashish R. Mohan', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-MA'}
# {'titre': 'Welcome to Monster High: The Origin Story', 'Directeur': 'Stephen Donnelly, Olly Reid, Jun Falkenstein', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'TV-Y7'}
# {'titre': 'Welcome to New York', 'Directeur': 'Abel Ferrara', 'Pays': 'United States, France', 'Année de sortie': '2014', 'Note': 'R'}
# {'titre': 'Welcome to Willits', 'Directeur': 'Trevor Ryan', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Westerplatte Resists', 'Directeur': 'Stanisław Różewicz', 'Pays': 'Poland', 'Année de sortie': '1967', 'Note': 'TV-MA'}
# {'titre': 'Westside vs. the World', 'Directeur': 'Michael Fahey', 'Pays': '', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'What a Wonderful Family!', 'Directeur': 'Huang Lei', 'Pays': 'China', 'Année de sortie': '2017', 'Note': 'TV-14'}
# {'titre': 'What Lies Beneath', 'Directeur': 'Robert Zemeckis', 'Pays': 'United States', 'Année de sortie': '2000', 'Note': 'PG-13'}
# {'titre': 'What Makes a Psychopath?', 'Directeur': 'Rebecca Harrison', 'Pays': 'United Kingdom', 'Année de sortie': '2017', 'Note': 'TV-14'}
# {'titre': 'What Still Remains', 'Directeur': 'Josh Mendoza', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': "What's Up With Love?", 'Directeur': 'Rudy Soedjarwo, Riri Riza', 'Pays': 'Indonesia', 'Année de sortie': '2002', 'Note': 'R'}
# {'titre': 'When Hari Got Married', 'Directeur': 'Ritu Sarin, Tenzing Sonam', 'Pays': 'United Kingdom, India, United States', 'Année de sortie': '2013', 'Note': 'NR'}
# {'titre': 'When Two Worlds Collide', 'Directeur': 'Heidi Brandenburg, Mathew Orzel', 'Pays': 'Peru, United States, United Kingdom', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Where the Money Is', 'Directeur': 'Marek Kanievska', 'Pays': 'Germany, United States, United Kingdom, Canada', 'Année de sortie': '2000', 'Note': 'PG-13'}
# {'titre': "Where's the Money", 'Directeur': 'Scott Zabielski', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'R'}
# {'titre': "While We're Young", 'Directeur': 'Noah Baumbach', 'Pays': 'United States', 'Année de sortie': '2015', 'Note': 'R'}
# {'titre': 'White Chamber', 'Directeur': 'Paul Raschid', 'Pays': 'United Kingdom', 'Année de sortie': '2018', 'Note': 'TV-MA'}
# {'titre': 'White Island', 'Directeur': 'Benjamin Turner', 'Pays': 'United Kingdom', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'Who the F**k Is That Guy?', 'Directeur': 'Drew Stone', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': "Who's That Knocking at My Door?", 'Directeur': 'Martin Scorsese', 'Pays': 'United States', 'Année de sortie': '1967', 'Note': 'R'}
# {'titre': 'Why Are We Getting So Fat?', 'Directeur': 'Milla Harrison-Hansley, Alicky Sussman', 'Pays': 'United Kingdom', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Why Knot', 'Directeur': 'Dhruv Dhawan', 'Pays': 'Canada, India, Thailand, United States, United Arab Emirates', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'Why We Fight: The Battle of Russia', 'Directeur': 'Frank Capra, Anatole Litvak', 'Pays': 'United States', 'Année de sortie': '1943', 'Note': 'TV-PG'}
# {'titre': 'Wild Wild West', 'Directeur': 'Barry Sonnenfeld', 'Pays': 'United States', 'Année de sortie': '1999', 'Note': 'PG-13'}
# {'titre': 'Wildlife', 'Directeur': 'Paul Dano', 'Pays': 'United States', 'Année de sortie': '2018', 'Note': 'PG-13'}
# {'titre': 'Williams', 'Directeur': 'Morgan Matthews', 'Pays': 'United Kingdom', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Willy Wonka & the Chocolate Factory', 'Directeur': 'Mel Stuart', 'Pays': 'United States, East Germany, West Germany', 'Année de sortie': '1971', 'Note': 'G'}
# {'titre': 'Winnie', 'Directeur': 'Pascale Lamche', 'Pays': 'France, Netherlands, South Africa, Finland', 'Année de sortie': '2017', 'Note': 'TV-14'}
# {'titre': 'Winter of Our Dreams', 'Directeur': 'John Duigan', 'Pays': 'Australia', 'Année de sortie': '1981', 'Note': 'NR'}
# {'titre': "Winter's Bone", 'Directeur': 'Debra Granik', 'Pays': 'United States', 'Année de sortie': '2010', 'Note': 'R'}
# {'titre': 'Wish I Was Here', 'Directeur': 'Zach Braff', 'Pays': 'United States', 'Année de sortie': '2014', 'Note': 'R'}
# {'titre': 'Wish Man', 'Directeur': 'Theo Davies', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-14'}
# {'titre': 'Withdrawn', 'Directeur': 'Adrian Murray', 'Pays': 'Canada', 'Année de sortie': '2017', 'Note': 'TV-MA'}
# {'titre': 'Wolves', 'Directeur': 'Bart Freundlich', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'R'}
# {'titre': 'Woodstock', 'Directeur': 'Barak Goodman', 'Pays': 'United States', 'Année de sortie': '2019', 'Note': 'TV-MA'}
# {'titre': 'World Trade Center', 'Directeur': 'Oliver Stone', 'Pays': 'United States', 'Année de sortie': '2006', 'Note': 'PG-13'}
# {'titre': "World's Weirdest Homes", 'Directeur': 'Storm Theunissen', 'Pays': '', 'Année de sortie': '2015', 'Note': 'TV-PG'}
# {'titre': 'Would You Rather', 'Directeur': 'David Guy Levy', 'Pays': 'United States', 'Année de sortie': '2013', 'Note': 'TV-MA'}
# {'titre': 'Wrong No.', 'Directeur': 'Yasir Nawaz', 'Pays': 'Pakistan', 'Année de sortie': '2015', 'Note': 'TV-14'}
# {'titre': 'Wrong Side Raju', 'Directeur': 'Mikhil Musale', 'Pays': 'India', 'Année de sortie': '2016', 'Note': 'TV-MA'}
# {'titre': 'WWII: Report from the Aleutians', 'Directeur': 'John Huston', 'Pays': 'United States', 'Année de sortie': '1943', 'Note': 'TV-PG'}
# {'titre': 'Wyatt Earp', 'Directeur': 'Lawrence Kasdan', 'Pays': 'United States', 'Année de sortie': '1994', 'Note': 'PG-13'}
# {'titre': 'XX', 'Directeur': 'Jovanka Vuckovic, Annie Clark, Roxanne Benjamin, Karyn Kusama', 'Pays': 'Canada, United States', 'Année de sortie': '2017', 'Note': 'R'}
# {'titre': 'XXx', 'Directeur': 'Rob Cohen', 'Pays': 'United States', 'Année de sortie': '2002', 'Note': 'PG-13'}
# {'titre': 'XXX: State of the Union', 'Directeur': 'Lee Tamahori', 'Pays': 'United States', 'Année de sortie': '2005', 'Note': 'PG-13'}
# {'titre': 'Y Tu Mamá También', 'Directeur': 'Alfonso Cuarón', 'Pays': 'Mexico', 'Année de sortie': '2001', 'Note': 'R'}
# {'titre': 'Y.M.I.: Yeh Mera India', 'Directeur': 'N. Chandra', 'Pays': 'India', 'Année de sortie': '2008', 'Note': 'TV-MA'}
# {'titre': 'Yaadein', 'Directeur': 'Subhash Ghai', 'Pays': 'India', 'Année de sortie': '2001', 'Note': 'TV-14'}
# {'titre': 'Yaara O Dildaara', 'Directeur': 'Ksshitij Chaudhary', 'Pays': 'India', 'Année de sortie': '2011', 'Note': 'TV-14'}
# {'titre': 'Yamla Pagla Deewana 2', 'Directeur': 'Sangeeth Sivan', 'Pays': 'India', 'Année de sortie': '2013', 'Note': 'TV-14'}
# {'titre': 'Yanda Kartavya Aahe', 'Directeur': 'Kedar Shinde', 'Pays': 'India', 'Année de sortie': '2006', 'Note': 'TV-PG'}
# {'titre': 'يوم الدين', 'Directeur': 'Abu Bakr Shawky', 'Pays': 'Egypt, Austria, United States', 'Année de sortie': '2018', 'Note': 'TV-14'}
# {'titre': 'Yellowbird', 'Directeur': 'Christian De Vita', 'Pays': 'France, Belgium', 'Année de sortie': '2014', 'Note': 'PG'}
# {'titre': 'Yes or No', 'Directeur': 'Saratswadee Wongsomphet', 'Pays': 'Thailand', 'Année de sortie': '2010', 'Note': 'TV-PG'}
# {'titre': 'Yes or No 2', 'Directeur': 'Saratswadee Wongsomphet', 'Pays': 'Thailand', 'Année de sortie': '2012', 'Note': 'TV-PG'}
# {'titre': 'Yes or No 2.5', 'Directeur': 'Kirati Nakintanon', 'Pays': 'Thailand', 'Année de sortie': '2015', 'Note': 'TV-PG'}
# {'titre': 'Yo-Kai Watch: The Movie', 'Directeur': 'Mark Risley', 'Pays': 'Japan, United States', 'Année de sortie': '2016', 'Note': 'TV-Y7'}
# {'titre': 'Yoga Hosers', 'Directeur': 'Kevin Smith', 'Pays': 'United States', 'Année de sortie': '2016', 'Note': 'PG-13'}
# {'titre': 'Yoko and His Friends', 'Directeur': '', 'Pays': 'Russia, Spain', 'Année de sortie': '2015', 'Note': 'TV-Y'}
# {'titre': 'You Can Tutu', 'Directeur': 'James Brown', 'Pays': 'United Kingdom', 'Année de sortie': '2017', 'Note': 'TV-G'}
# {'titre': 'You Can’t Fight Christmas', 'Directeur': 'Kenny Young', 'Pays': 'United States', 'Année de sortie': '2017', 'Note': 'TV-PG'}
# {'titre': 'You Carry Me', 'Directeur': 'Ivona Juka', 'Pays': 'Croatia, Slovenia, Serbia, Montenegro', 'Année de sortie': '2015', 'Note': 'TV-MA'}
# {'titre': 'You Changed My Life', 'Directeur': 'Cathy Garcia-Molina', 'Pays': 'Philippines', 'Année de sortie': '2009', 'Note': 'TV-PG'}
# {'titre': "You Don't Mess with the Zohan", 'Directeur': 'Dennis Dugan', 'Pays': 'United States', 'Année de sortie': '2008', 'Note': 'UR'}
# {'titre': 'Young Adult', 'Directeur': 'Jason Reitman', 'Pays': 'United States', 'Année de sortie': '2011', 'Note': 'R'}
# {'titre': 'Young Tiger', 'Directeur': 'Mu Chu', 'Pays': 'Hong Kong', 'Année de sortie': '1973', 'Note': 'NR'}
# {'titre': 'Yours, Mine and Ours', 'Directeur': 'Raja Gosnell', 'Pays': 'United States', 'Année de sortie': '2005', 'Note': 'PG'}
# {'titre': 'اشتباك', 'Directeur': 'Mohamed Diab', 'Pays': 'Egypt, France', 'Année de sortie': '2016', 'Note': 'TV-14'}
# {'titre': 'Zed Plus', 'Directeur': 'Chandra Prakash Dwivedi', 'Pays': 'India', 'Année de sortie': '2014', 'Note': 'TV-MA'}
# {'titre': 'Zenda', 'Directeur': 'Avadhoot Gupte', 'Pays': 'India', 'Année de sortie': '2009', 'Note': 'TV-14'}
# {'titre': 'Zinzana', 'Directeur': 'Majid Al Ansari', 'Pays': 'United Arab Emirates, Jordan', 'Année de sortie': '2015', 'Note': 'TV-MA'}
# {'titre': 'Zodiac', 'Directeur': 'David Fincher', 'Pays': 'United States', 'Année de sortie': '2007', 'Note': 'R'}
# {'titre': 'Zombieland', 'Directeur': 'Ruben Fleischer', 'Pays': 'United States', 'Année de sortie': '2009', 'Note': 'R'}
# {'titre': 'Zoom', 'Directeur': 'Peter Hewitt', 'Pays': 'United States', 'Année de sortie': '2006', 'Note': 'PG'}
# {'titre': 'Zubaan', 'Directeur': 'Mozez Singh', 'Pays': 'India', 'Année de sortie': '2015', 'Note': 'TV-14'}

# %% [markdown]
# # Bonus (Mandatory)

# %% [markdown]
# ## Github
# Pour soumettre votre travail:
#
# 1.   Commit changes to a branch and push to [github](https://google.com)
# 2.   Create pull request / merge request
