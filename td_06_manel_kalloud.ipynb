# %% [markdown]
# <a href="https://colab.research.google.com/github/lapointe05/m1-miage/blob/manel_kalloud_td06/td_06_manel_kalloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/fr/0/0b/Polytech_Lyon_logo.png" alt="drawing" height="200"/>
#
# # Traitement de données & Programmation en Python
# ---

# %% [markdown]
# # TD 06
#
# Traitement de données
#
# Elements à consulter:
#
#
#
#
#
# Doc                                   |             Link
# --------------------------------------|------------------------------------
# Github Helper      | [>link<](#scrollTo=Github_101)
# Python en 30 jours | [>link<](https://moncoachdata.com/courses/apprendre-python-en-30-jours/)
# Get started with pandas | [>link<](https://colab.research.google.com/notebooks/snippets/pandas.ipynb)

# %% [markdown]
# ## Intro
#
# Le premier bloc devrait toujours contenir les installs/imports dont on aura besoin pour le reste

# %%
# Installs
print("Python is awesome 👍")

# %% [markdown]
# ## EX01
# ### Dataframes
#
# * Importer la librairie pandas
# * lire dataset 'tv_shows.csv' dans une variable tv_data
# * Afficher les 10 premieres lignes du dataset
# * Créer une colonne "sreaming_platform" qui contient le nom de la plateforme de streaming en se basant sur les colonnes (hulu, prime, disney, netflix)
# * Drop les colonnes (hulu, prime, disney, netflix)
# * Afficher le nombre de shows par plateforme de streaming
# * Afficher la note moyenne (imdb) par plateforme de streaming
# * Assigner a une variable top_shows, les meilleurs shows par plateforme de streaming et afficher cette dernière
# > bonus
# * Faire un graphique avec le nombre de shows par année (sur Y, et sur l'axe X les années) par plateforme de streaming (en series). Libres sur le choix du graphique [help](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html)

# %%
# Importer la librairie pandas
import pandas as pd
import numpy as np

# lire dataset 'tv_shows.csv' dans une variable tv_data
file_path = "./tv_shows.csv"
tv_data = pd.read_csv(file_path, delimiter='|')

#Afficher les 10 premieres lignes du dataset
# print(tv_data[:10])
tv_data.head()
# Out:
#    ID             Title  Year  Age    IMDb Rotten Tomatoes  Netflix  Hulu  \
# 0   1      Breaking Bad  2008  18+  9.4/10         100/100        1     0
# 1   2   Stranger Things  2016  16+  8.7/10          96/100        1     0
# 2   3   Attack on Titan  2013  18+  9.0/10          95/100        1     1
# 3   4  Better Call Saul  2015  18+  8.8/10          94/100        1     0
# 4   5              Dark  2017  16+  8.8/10          93/100        1     0
#
#    Prime Video  Disney+  Type
# 0            0        0     1
# 1            0        0     1
# 2            0        0     1
# 3            0        0     1
# 4            0        0     1

# %%
from pandas.core.groupby.groupby import T


print("--------------------------------------Sreaming_platform-------------------------------------------------------------")
# Créer une colonne "sreaming_platform" qui contient le nom de la plateforme de streaming en se basant sur les colonnes (hulu, prime, disney, netflix)
conditions = [tv_data['Netflix']==1, tv_data['Disney+']==1, tv_data['Hulu']==1, tv_data['Prime Video']==1,]
choices = ['Netflix','Disney+','Hulu', 'Prime Video']
stream = tv_data.assign(sreaming_platform = np.select(conditions, choices, default=np.nan))
print(stream)
#solution optimale = methode melt, à tester

print("---------------------------------------Drop Plateformes-----------------------------------------------------------")


# Drop les colonnes (hulu, prime, disney, netflix) en conservant streaming platform
drop_col_stream = tv_data.assign(sreaming_platform = np.select(conditions, choices, default=np.nan)).drop(['Netflix','Disney+','Hulu', 'Prime Video'], axis=1) # nan = not a number
print(drop_col_stream.head())
# Drop les colonnes (hulu, prime, disney, netflix) sans conserver streaming platform
tv_data.drop(['Netflix','Disney+','Hulu', 'Prime Video'], axis=1)

print("-----------------------------------------Nombre de show par plateforme------------------------------------------------------------")


# Afficher le nombre de shows par plateforme de streaming
n = tv_data['Netflix'].sum()
print ("Netflix show:",n)
d = tv_data['Disney+'].sum()
print ("Disney+ show:",d)
h = tv_data['Hulu'].sum()
print ("Hulu show:",h)
p = tv_data['Prime Video'].sum()
print ("Prime Video show:",p) 

print("----------------------------------------Nombre de show par plateforme 2----------------------------------------------------------")

print(stream['sreaming_platform'].value_counts())

# sum_show = tv_data.groupby(by=['Netflix','Disney+','Hulu', 'Prime Video']).sum().groupby(level=[0]).cumsum()
# print(sum_show)  ---------------- Pas compris

print("---------------------------------------Note moyenne par plateforme--------------------------------------------------------------------")

# Afficher la note moyenne (imdb) par plateforme de streaming

#Split la colonne IMDb pour récupérer la note
drop_col_stream[['IMDb','/10']] = drop_col_stream['IMDb'].str.split('/',expand=True)
#print(drop_col_stream)

#Convertit le type de la colonne de chaine de caractère à float
drop_col_stream['IMDb']=pd.to_numeric(drop_col_stream['IMDb'],errors='coerce').fillna(0)

#Moyenne avec groupBy 
show_mean = drop_col_stream.groupby('sreaming_platform')['IMDb'].mean()
print(show_mean)

#split data pour ne récupérer que ce qu'il y a avant le slash pour calculer la moyenne

print("----------------------------------------Meilleurs show par plateforme------------------------------------------------------------------")

# Assigner a une variable top_shows, les meilleurs shows par plateforme de streaming et afficher cette dernière
# drop_col_stream.dropna(axis=0)

top_show = drop_col_stream.groupby('sreaming_platform')['IMDb'].apply(lambda x: x.idxmax()) #?
print(top_show)



#Questions: Pourquoi le dataframe s'affiche sans faire de print ?
#           Si plusieurs plateforme pour un show, comment gérer l'affichage ?
#           Modifier le fichier csv  ?
#           index  ?
# Out:
# --------------------------------------Sreaming_platform-------------------------------------------------------------
#         ID                                  Title  Year  Age    IMDb  \
# 0        1                           Breaking Bad  2008  18+  9.4/10
# 1        2                        Stranger Things  2016  16+  8.7/10
# 2        3                        Attack on Titan  2013  18+  9.0/10
# 3        4                       Better Call Saul  2015  18+  8.8/10
# 4        5                                   Dark  2017  16+  8.8/10
# ...    ...                                    ...   ...  ...     ...
# 5363  5713                       Paradise Islands  2017  NaN     NaN
# 5364  5714                         Mexico Untamed  2018  NaN     NaN
# 5365  5715                  Wild Centeral America  2020  NaN     NaN
# 5366  5716                            Wild Russia  2018  NaN     NaN
# 5367  5717  Fearless Adventures with Jack Randall  2018  NaN     NaN
#
# ...

# %%
from matplotlib import pyplot as plt
# Faire un graphique avec le nombre de shows par année (sur Y, et sur l'axe X les années) par plateforme de streaming (en series). Libres sur le choix du graphique help

#creer data frame avec 3 col = plateforme, nb de sw=how, année | on obtiendra 4*nb annne ligne
graph = drop_col_stream.plot.bar( x='Year', y="", rot=0)

#on obtient un graphe avec 4 bare pour chauqe année qui represente les plateformes
# Out:
# Error in callback <function flush_figures at 0x7fe997dc7af0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...
