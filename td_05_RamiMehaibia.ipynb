# %% [markdown]
# <a href="https://colab.research.google.com/github/lapointe05/m1-miage/blob/Rayene_Hakoume/td_05_RamiMehaibia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/fr/0/0b/Polytech_Lyon_logo.png" alt="drawing" height="200"/>
#
# # Traitement de données & Programmation en Python
# ---

# %% [markdown]
# # TD 05
#
# Traitement de données
#
# ![Good luck!](https://media.tenor.com/YoFWnXe4V3kAAAAd/may-the-odds-be-ever-in-your-favor-may-the-odds-hunger-games.gif)
#
# Elements à consulter:
#
#
#
#
#
# Doc                                   |             Link
# --------------------------------------|------------------------------------
# Github Helper      | [>link<](#scrollTo=Github_101)
# Python en 30 jours | [>link<](https://moncoachdata.com/courses/apprendre-python-en-30-jours/)
# Get started with pandas | [>link<](https://colab.research.google.com/notebooks/snippets/pandas.ipynb)

# %% [markdown]
# ## Intro
#
# Le premier bloc devrait toujours contenir les installs/imports dont on aura besoin pour le reste

# %%
# Installs
print("Python is awesome 👍")
# Out:
# Python is awesome 👍

# %%
# Imports
import os
import json
from random import randint
import pandas as pd
import numpy as np

# %%
x = np.array([[1, 2, 3], [4, 5, 6]], np.int32)

x.shape
# Out:
# (2, 3)

# %% [markdown]
# ### Correction TD precedent
#
# Partir d'un fichier csv et alimenter la binge watch list :
#   > serie, plateform, nb_episodes, année_sortie, note
#
# Puis print :
#
# 	 Nom de la série : Brooklyn Nine-Nine
# 	 Année de sortie : 2013
#
# 	 Nom de la série : The office
# 	 Année de sortie : 2005

# %%
def csv_to_dict(file_path, separator=";", row_limit=None):
    """
    Transforms a csv file, into a list of dictionaries

    Arguments:
        file_path  {str} : eg. /documents/file.txt
        separator  {str} : separator of fields, default (;)
        row_limit  {int} : limit the rows to be read, default None

    Returns list[dict]
    """

    with open(file_path, "r") as f:
        serie = {}
        serie_list = []
        for i, row in enumerate(f, 1):
            if i == 1:
                header = row.lower().strip().replace(' ','_').split(separator)
                # print("\nHeaders:", header,"\n")
            else:
                data = row.lower().strip().split(separator)
                # print("Data:",data)
                if len(header) == len(data):
                    for j, element in enumerate(header):
                        serie[header[j]] = data[j]
            # print(serie)
                serie_list.append(serie)
                serie = {}
            if i == row_limit:
                break
    return serie_list



file_path = "./netflix_titles.csv"
# file_path = "./tv_shows_pipe.csv"
limit = None
binge_watch_list = csv_to_dict(file_path,separator="|",row_limit=limit)
# for serie in binge_watch_list:
#   print(serie.get('title'))
# # Option 1 read some rows to see what we have

df = pd.DataFrame(binge_watch_list)
df["title"] = df["title"].str.title()
df.head(5)

column_name = 'release_year'
filter = df['release_year'] == '2005'
# df.query(f"`{column_name}` == '2003'")
df[filter]
# # serie, plateform, nb_episodes, année_sortie, note
# df2 = df.melt(id_vars=['title','year','imdb','rotten_tomatoes'],
#               var_name='plateform', 
#               value_vars=['netflix','hulu','prime_video','disney+'])
# df2.drop(['value'], axis=1)

# %% [markdown]
# ##EX01
# ### Numpy intro
#
# * Créer un vecteur depuis la liste ['Lyon', 'Paris', 'Montpellier']
#     * Assigner le résultat à la variable `villes`
# * Créer une matrice depuis la liste de listes suivante: `[['Lyon', '69'], ['Paris', '75'], ['Montpellier','34']]`
#     * Assigner le résultat à la variable `villes_departement`
# * Assigner la taille du vecteur `villes` à la variable `v_shape`
# * Assigner la taille du tableau `villes_departement` à la variable `vd_shape`
# * Afficher les résultats

# %%
# Code here
import numpy as np
ville= ['Lyon', 'Paris', 'Montpellier']
Villes=np.array(ville)

print(type(Villes))
villes_dep = [['Lyon', '69'], ['Paris', '75'], ['Montpellier','34']]

villes_departement = np.array(villes_dep)
print(villes_departement)

v_shape=np.shape(Villes)
vd_shape=np.shape(villes_departement)
print("ville",v_shape)
print("villes_departement",vd_shape)
# Out:
# <class 'numpy.ndarray'>
# [['Lyon' '69']
#  ['Paris' '75']
#  ['Montpellier' '34']]
# ville (3,)
# villes_departement (3, 2)

# %% [markdown]
# ##EX02
# ### Numpy intro
#
# #### Part 1
#
# * Telecharger le dataset [cereal.csv](https://www.kaggle.com/datasets/crawford/80-cereals?select=cereal.csv) avec les colonnes suivantes :
#
# ```
# ['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
# 'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
# 'rating']
# ```
#
# * Afficher les deux premieres colonnes et toute les lignes
# * Afficher la dernière colonne
# * Afficher les 5 premieres lignes de la 4ème colonne
# * Assigner a une variable `corn_flakes_cals` le nombre de calories par 100 gr de céréales de la marque Corn Flakes
# * Assigner le nom de la 3eme marque sur le dataset a une variabe `third_brand`
# * Mettre dans une liste toutes les marques de céreales en utilisant `.tolist()` & afficher cette dernière
# * Mettre les 10 premiere marques dans le fichiers dans une liste `first_ten_brands` & afficher cette dernière
# > bonus
# * Convertir la colonne ratings en décimale

# %%
# Code here
import numpy as np
file_path = "./cereal.csv"
data=np.genfromtxt(file_path, dtype='str', delimiter=',', autostrip=True, skip_header=1,max_rows=None)



# afficher les donnees
print(data)
#Afficher les deux premieres colonnes et toute les lignes
print(data[:,0:2])
#Afficher la dernière colonne
print(data[:,-1])
#Afficher les 5 premieres lignes de la 4ème colonne
print(data[0:5,4])

#Assigner a une variable corn_flakes_cals le nombre de calories par 100 gr de céréales de la marque Corn Flakes
corn_flakes = (data[:,0] == 'Corn Flakes')
print(corn_flakes)


corn_flakes_cals = data[corn_flakes,3]
print(corn_flakes_cals)

# Assigner le nom de la 3 eme marque sur le dataset a une variabe third_brand

third_brand = data[2,0]
print(third_brand)

#Mettre dans une liste toutes les marques de céreales en utilisant .tolist() & afficher cette dernière

brand_list = data[:,0].tolist()
print("toute marques: ",brand_list)

#Mettre les 10 premiere marques dans le fichiers dans une liste first_ten_brands & afficher cette dernière

first_ten_brands = data[:10,0].tolist()
print("first ten  brands : ",first_ten_brands)
# Out:
# [['100% Bran' 'N' 'C' ... '1' '0.33' '68.402973']
#  ['100% Natural Bran' 'Q' 'C' ... '1' '1' '33.983679']
#  ['All-Bran' 'K' 'C' ... '1' '0.33' '59.425505']
#  ...
#  ['Wheat Chex' 'R' 'C' ... '1' '0.67' '49.787445']
#  ['Wheaties' 'G' 'C' ... '1' '1' '51.592193']
#  ['Wheaties Honey Gold' 'G' 'C' ... '1' '0.75' '36.187559']]
# [['100% Bran' 'N']
#  ['100% Natural Bran' 'Q']
#  ['All-Bran' 'K']
#  ['All-Bran with Extra Fiber' 'K']
#  ['Almond Delight' 'R']
#  ['Apple Cinnamon Cheerios' 'G']
#  ['Apple Jacks' 'K']
#  ['Basic 4' 'G']
#  ['Bran Chex' 'R']
#  ['Bran Flakes' 'P']
#  ["Cap'n'Crunch" 'Q']
#  ['Cheerios' 'G']
#  ['Cinnamon Toast Crunch' 'G']
#  ['Clusters' 'G']
#  ['Cocoa Puffs' 'G']
#  ['Corn Chex' 'R']
#  ['Corn Flakes' 'K']
#  ['Corn Pops' 'K']
#  ['Count Chocula' 'G']
#  ["Cracklin' Oat Bran" 'K']
#  ['Cream of Wheat (Quick)' 'N']
#  ['Crispix' 'K']
#  ['Crispy Wheat & Raisins' 'G']
#  ['Double Chex' 'R']
#  ['Froot Loops' 'K']
#  ['Frosted Flakes' 'K']
#  ['Frosted Mini-Wheats' 'K']
#  ['Fruit & Fibre Dates; Walnuts; and Oats' 'P']
#  ['Fruitful Bran' 'K']
#  ['Fruity Pebbles' 'P']
#  ['Golden Crisp' 'P']
#  ['Golden Grahams' 'G']
#  ['Grape Nuts Flakes' 'P']
#  ['Grape-Nuts' 'P']
#  ['Great Grains Pecan' 'P']
#  ['Honey Graham Ohs' 'Q']
#  ['Honey Nut Cheerios' 'G']
#  ['Honey-comb' 'P']
#  ['Just Right Crunchy  Nuggets' 'K']
#  ['Just Right Fruit & Nut' 'K']
#  ['Kix' 'G']
#  ['Life' 'Q']
#  ['Lucky Charms' 'G']
#  ['Maypo' 'A']
#  ['Muesli Raisins; Dates; & Almonds' 'R']
#  ['Muesli Raisins; Peaches; & Pecans' 'R']
#  ['Mueslix Crispy Blend' 'K']
#  ['Multi-Grain Cheerios' 'G']
#  ['Nut&Honey Crunch' 'K']
#  ['Nutri-Grain Almond-Raisin' 'K']
#  ['Nutri-grain Wheat' 'K']
#  ['Oatmeal Raisin Crisp' 'G']
#  ['Post Nat. Raisin Bran' 'P']
#  ['Product 19' 'K']
#  ['Puffed Rice' 'Q']
#  ['Puffed Wheat' 'Q']
#  ['Quaker Oat Squares' 'Q']
#  ['Quaker Oatmeal' 'Q']
#  ['Raisin Bran' 'K']
#  ['Raisin Nut Bran' 'G']
#  ['Raisin Squares' 'K']
#  ['Rice Chex' 'R']
#  ['Rice Krispies' 'K']
#  ['Shredded Wheat' 'N']
#  ["Shredded Wheat 'n'Bran" 'N']
#  ['Shredded Wheat spoon size' 'N']
#  ['Smacks' 'K']
#  ['Special K' 'K']
#  ['Strawberry Fruit Wheats' 'N']
#  ['Total Corn Flakes' 'G']
#  ['Total Raisin Bran' 'G']
#  ['Total Whole Grain' 'G']
#  ['Triples' 'G']
#  ['Trix' 'G']
#  ['Wheat Chex' 'R']
#  ['Wheaties' 'G']
#  ['Wheaties Honey Gold' 'G']]
# ['68.402973' '33.983679' '59.425505' '93.704912' '34.384843' '29.509541'
#  '33.174094' '37.038562' '49.120253' '53.313813' '18.042851' '50.764999'
#  '19.823573' '40.400208' '22.736446' '41.445019' '45.863324' '35.782791'
#  '22.396513' '40.448772' '64.533816' '46.895644' '36.176196' '44.330856'
#  '32.207582' '31.435973' '58.345141' '40.917047' '41.015492' '28.025765'
#  '35.252444' '23.804043' '52.076897' '53.371007' '45.811716' '21.871292'
#  '31.072217' '28.742414' '36.523683' '36.471512' '39.241114' '45.328074'
#  '26.734515' '54.850917' '37.136863' '34.139765' '30.313351' '40.105965'
#  '29.924285' '40.692320' '59.642837' '30.450843' '37.840594' '41.503540'
#  '60.756112' '63.005645' '49.511874' '50.828392' '39.259197' '39.703400'
#  '55.333142' '41.998933' '40.560159' '68.235885' '74.472949' '72.801787'
#  '31.230054' '53.131324' '59.363993' '38.839746' '28.592785' '46.658844'
#  '39.106174' '27.753301' '49.787445' '51.592193' '36.187559']
# ['4' '3' '4' '4' '2']
# [False False False False False False False False False False False False
#  False False False False  True False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]
# ['100']
# All-Bran
# toute marques:  ['100% Bran', '100% Natural Bran', 'All-Bran', 'All-Bran with Extra Fiber', 'Almond Delight', 'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex', 'Bran Flakes', "Cap'n'Crunch", 'Cheerios', 'Cinnamon Toast Crunch', 'Clusters', 'Cocoa Puffs', 'Corn Chex', 'Corn Flakes', 'Corn Pops', 'Count Chocula', "Cracklin' Oat Bran", 'Cream of Wheat (Quick)', 'Crispix', 'Crispy Wheat & Raisins', 'Double Chex', 'Froot Loops', 'Frosted Flakes', 'Frosted Mini-Wheats', 'Fruit & Fibre Dates; Walnuts; and Oats', 'Fruitful Bran', 'Fruity Pebbles', 'Golden Crisp', 'Golden Grahams', 'Grape Nuts Flakes', 'Grape-Nuts', 'Great Grains Pecan', 'Honey Graham Ohs', 'Honey Nut Cheerios', 'Honey-comb', 'Just Right Crunchy  Nuggets', 'Just Right Fruit & Nut', 'Kix', 'Life', 'Lucky Charms', 'Maypo', 'Muesli Raisins; Dates; & Almonds', 'Muesli Raisins; Peaches; & Pecans', 'Mueslix Crispy Blend', 'Multi-Grain Cheerios', 'Nut&Honey Crunch', 'Nutri-Grain Almond-Raisin', 'Nutri-grain Wheat', 'Oatmeal Raisin Crisp', 'Post Nat. Raisin Bran', 'Product 19', 'Puffed Rice', 'Puffed Wheat', 'Quaker Oat Squares', 'Quaker Oatmeal', 'Raisin Bran', 'Raisin Nut Bran', 'Raisin Squares', 'Rice Chex', 'Rice Krispies', 'Shredded Wheat', "Shredded Wheat 'n'Bran", 'Shredded Wheat spoon size', 'Smacks', 'Special K', 'Strawberry Fruit Wheats', 'Total Corn Flakes', 'Total Raisin Bran', 'Total Whole Grain', 'Triples', 'Trix', 'Wheat Chex', 'Wheaties', 'Wheaties Honey Gold']
# first ten  brands :  ['100% Bran', '100% Natural Bran', 'All-Bran', 'All-Bran with Extra Fiber', 'Almond Delight', 'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex', 'Bran Flakes']

# %% [markdown]
# #### Part 2
#
# * **Extraire** la premiere colonne du dataset et **la comparer** à la valeur `'Special K'` Assigner le resultat à une variable `special_k`
# * Executer la commande `print(data[special_k])`
# > bonus
# * Faire la meme chose mais le filtre verifie que le manufacturer est Quaker Oats (lire la doc du dataset 😉)
# > bonus ²
# * Print le nom des marques dont le fabricant est `Quaker Oats` et qui contiennent **moins** de `10 grammes` de sucre par portion
# * Ajouter une marque de céréales "healthy" avec 0 grammes de sucre au dataset

# %%
# Code here
import numpy as np
file_path = "./cereal.csv"
data=np.genfromtxt(file_path, dtype='str', delimiter=',', autostrip=True, skip_header=1,max_rows=None)
#Extraire la premiere colonne du dataset et la comparer à la valeur 'Special K' Assigner le resultat à une variable special_k
special_k = data[:,0] == 'Special K'
print(data[special_k])
#Faire la meme chose mais le filtre verifie que le manufacturer est Quaker Oats (lire la doc du dataset 😉)

quaker_oats = data[:,1] == 'Quaker Oats'
print(quaker_oats)

print(data[quaker_oats & (data[:,7].astype(float) < 50),0])

#data = np.append(data,[['healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', '0', 'healthy', 'healthy', 'healthy']], axis=0)
#print(data)
# Out:
# [['Special K' 'K' 'C' '110' '6' '0' '230' '1' '16' '3' '55' '25' '1' '1'
#   '1' '53.131324']]
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]
# []

# %% [markdown]
# #### Part 3
#
# Sur le même dataset, à l'aide d'une boucle `for`:
#
#
# *   Créer un dictionnaire avec la moyenne de sucre par Fabricant de cérales
# *   Trouver la marque de céreales qui contient le plus de sucre par portion

# %%
import numpy as np
file_path = "./cereal.csv"
data=np.genfromtxt(file_path, dtype='str', delimiter=',', autostrip=True, skip_header=1,max_rows=None)

sugar_dict = {}
for i in np.unique(data[:,1]):
    sugar_dict[i] = np.mean(data[data[:,1] == i,9].astype(float))
print(sugar_dict)

print(data[data[:,9].astype(float).argmax(),0])
# Out:
# {'A': 3.0, 'G': 7.954545454545454, 'K': 7.565217391304348, 'N': 1.8333333333333333, 'P': 8.777777777777779, 'Q': 5.25, 'R': 6.125}
# Golden Crisp

# %%
# Out:
# {'Ralston Purina': 6.125, 'Nabisco': 1.8333333333333333, 'General Mills': 7.954545454545454, 'Kelloggs': 7.565217391304348, 'American Home Food Products': 3.0, 'Post': 8.777777777777779, 'Quaker Oats': 5.25}

# %% [markdown]
# ## EX03
# ### Dataframes
#
# Refaire l'exo du TD 4 (fichier des series) en utilisant la librairie NumPy.

# %%
import numpy as np
file_path = "./netflix_titles.csv"
data=np.genfromtxt(file_path, dtype='str', delimiter=',', autostrip=True, skip_header=1,max_rows=None)

series = {}
for serie in data:
    if serie[1]=="TV Show":
        series[serie[0]]= {'Titre de la serie' : serie[2], 'Plateforme de streaming' : serie[8], "Nombre d épisodes" : serie[9], 'Année de sortie': serie[7], 'note /10 \n' : serie[5]}

print(series)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-c4f55f2fd286> in <module>
#       1 import numpy as np
#       2 file_path = "./netflix_titles.csv"
# ----> 3 data=np.genfromtxt(file_path, dtype='str', delimiter=',', autostrip=True, skip_header=1,max_rows=None)
#       4
#       5 series = {}
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    2122             # Raise an exception ?
#    2123             if invalid_raise:
# -> 2124                 raise ValueError(errmsg)
#    2125             # Issue a warning ?
#    2126             else:
#
# ValueError: Some errors were detected !
#     Line #3 (got 34 columns instead of 14)
#     Line #4 (got 24 columns instead of 14)
#     Line #5 (got 15 columns instead of 14)
#     Line #6 (got 23 columns instead of 14)
#     Line #7 (got 31 columns instead of 14)
#     Line #8 (got 26 columns instead of 14)
#     Line #9 (got 29 columns instead of 14)
#     Line #10 (got 18 columns instead of 14)
#     Line #11 (got 24 columns instead of 14)
#     Line #12 (got 16 columns instead of 14)
#     Line #13 (got 40 columns instead of 14)
#     Line #14 (got 26 columns instead of 14)
#     Line #15 (got 24 columns instead of 14)
#     Line #16 (got 15 columns instead of 14)
#     Line #17 (got 21 columns instead of 14)
#     Line #18 (got 16 columns instead of 14)
#     Line #19 (got 26 columns instead of 14)
#     Line #20 (got 23 columns instead of 14)
#     Line #21 (got 23 columns instead of 14)
#     Line #22 (got 17 columns instead of 14)
#     Line #23 (got 25 columns instead of 14)
#     Line #24 (got 20 columns instead of 14)
#     Line #25 (got 18 columns instead of 14)
#     Line #26 (got 19 columns instead of 14)
#     Line #27 (got 16 columns instead of 14)
#     Line #28 (got 20 columns instead of 14)
#     Line #29 (got 24 columns instead of 14)
#     Line #30 (got 24 columns instead of 14)
#     Line #31 (got 25 columns instead of 14)
#     Line #32 (got 25 columns instead of 14)
#     Line #33 (got 23 columns instead of 14)
#     Line #34 (got 22 columns instead of 14)
#     Line #35 (got 25 columns instead of 14)
#     Line #36 (got 17 columns instead of 14)
#     Line #37 (got 25 columns instead of 14)
#     Line #38 (got 25 columns instead of 14)
#     Line #39 (got 19 columns instead of 14)
#     Line #40 (got 25 columns instead of 14)
#     Line #41 (got 20 columns instead of 14)
#     Line #42 (got 24 columns instead of 14)
#     Line #43 (got 26 columns instead of 14)
#     Line #44 (got 25 columns instead of 14)
#     Line #45 (got 25 columns instead of 14)
#     Line #46 (got 23 columns instead of 14)
#     Line #48 (got 24 columns instead of 14)
#     Line #49 (got 26 columns instead of 14)
#     Line #50 (got 24 columns instead of 14)
#     Line #51 (got 29 columns instead of 14)
#     Line #52 (got 24 columns instead of 14)
#     Line #53 (got 25 columns instead of 14)
#     Line #54 (got 22 columns instead of 14)
#     Line #55 (got 27 columns instead of 14)
#     Line #56 (got 25 columns instead of 14)
#     Line #57 (got 16 columns instead of 14)
#     Line #58 (got 25 columns instead of 14)
#     Line #59 (got 28 columns instead of 14)
#     Line #60 (got 28 columns instead of 14)
#     Line #61 (got 36 columns instead of 14)
#     Line #62 (got 30 columns instead of 14)
#     Line #63 (got 25 columns instead of 14)
#     Line #64 (got 26 columns instead of 14)
#     Line #65 (got 26 columns instead of 14)
#     Line #66 (got 15 columns instead of 14)
#     Line #67 (got 18 columns instead of 14)
#     Line #68 (got 15 columns instead of 14)
#     Line #69 (got 25 columns instead of 14)
#     Line #70 (got 18 columns instead of 14)
#     Line #72 (got 18 columns instead of 14)
#     Line #73 (got 21 columns instead of 14)
#     Line #74 (got 18 columns instead of 14)
#     Line #75 (got 22 columns instead of 14)
#     Line #77 (got 15 columns instead of 14)
#     Line #78 (got 42 columns instead of 14)
#     Line #79 (got 21 columns instead of 14)
#     Line #80 (got 17 columns instead of 14)
#     Line #81 (got 17 columns instead of 14)
#     Line #82 (got 20 columns instead of 14)
#     Line #83 (got 20 columns instead of 14)
#     Line #84 (got 29 columns instead of 14)
#     Line #85 (got 17 columns instead of 14)
#     Line #86 (got 27 columns instead of 14)
#     Line #87 (got 25 columns instead of 14)
#     Line #88 (got 21 columns instead of 14)
#     Line #89 (got 18 columns instead of 14)
#     Line #90 (got 16 columns instead of 14)
#     Line #91 (got 20 columns instead of 14)
#     Line #92 (got 23 columns instead of 14)
#     Line #93 (got 15 columns instead of 14)
#     Line #94 (got 25 columns instead of 14)
#     Line #95 (got 25 columns instead of 14)
#     Line #96 (got 26 columns instead of 14)
#     Line #97 (got 16 columns instead of 14)
#     Line #98 (got 24 columns instead of 14)
#     Line #99 (got 21 columns instead of 14)
#     Line #100 (got 27 columns instead of 14)
#     Line #101 (got 26 columns instead of 14)
#     Line #102 (got 22 columns instead of 14)
#     Line #103 (got 16 columns instead of 14)
#     Line #104 (got 15 columns instead of 14)
#     Line #105 (got 28 columns instead of 14)
#     Line #106 (got 16 columns instead of 14)
#     Line #107 (got 26 columns instead of 14)
#     Line #108 (got 21 columns instead of 14)
#     Line #109 (got 20 columns instead of 14)
#     Line #110 (got 23 columns instead of 14)
#     Line #111 (got 27 columns instead of 14)
#     Line #112 (got 16 columns instead of 14)
#     Line #113 (got 22 columns instead of 14)
#     Line #114 (got 21 columns instead of 14)
#     Line #115 (got 21 columns instead of 14)
#     Line #116 (got 24 columns instead of 14)
#     Line #117 (got 25 columns instead of 14)
#     Line #118 (got 22 columns instead of 14)
#     Line #120 (got 22 columns instead of 14)
#     Line #121 (got 20 columns instead of 14)
#     Line #122 (got 19 columns instead of 14)
#     Line #123 (got 28 columns instead of 14)
#     Line #124 (got 24 columns instead of 14)
#     Line #126 (got 17 columns instead of 14)
#     Line #127 (got 23 columns instead of 14)
#     Line #128 (got 22 columns instead of 14)
#     Line #129 (got 29 columns instead of 14)
#     Line #130 (got 25 columns instead of 14)
#     Line #131 (got 24 columns instead of 14)
#     Line #132 (got 20 columns instead of 14)
#     Line #133 (got 27 columns instead of 14)
#     Line #134 (got 29 columns instead of 14)
#     Line #135 (got 25 columns instead of 14)
#     Line #136 (got 28 columns instead of 14)
#     Line #137 (got 27 columns instead of 14)
#     Line #138 (got 27 columns instead of 14)
#     Line #139 (got 29 columns instead of 14)
#     Line #140 (got 25 columns instead of 14)
#     Line #141 (got 30 columns instead of 14)
#     Line #142 (got 23 columns instead of 14)
#     Line #143 (got 25 columns instead of 14)
#     Line #144 (got 26 columns instead of 14)
#     Line #145 (got 21 columns instead of 14)
#     Line #146 (got 27 columns instead of 14)
#     Line #147 (got 26 columns instead of 14)
#     Line #148 (got 24 columns instead of 14)
#     Line #150 (got 21 columns instead of 14)
#     Line #151 (got 26 columns instead of 14)
#     Line #152 (got 30 columns instead of 14)
#     Line #153 (got 26 columns instead of 14)
#     Line #154 (got 17 columns instead of 14)
#     Line #155 (got 18 columns instead of 14)
#     Line #156 (got 33 columns instead of 14)
#     Line #157 (got 26 columns instead of 14)
#     Line #158 (got 30 columns instead of 14)
#     Line #159 (got 22 columns instead of 14)
#     Line #160 (got 23 columns instead of 14)
#     Line #161 (got 26 columns instead of 14)
#     Line #162 (got 21 columns instead of 14)
#     Line #163 (got 27 columns instead of 14)
#     Line #164 (got 26 columns instead of 14)
#     Line #165 (got 26 columns instead of 14)
#     Line #166 (got 28 columns instead of 14)
#     Line #167 (got 23 columns instead of 14)
#     Line #168 (got 24 columns instead of 14)
#     Line #169 (got 26 columns instead of 14)
#     Line #170 (got 23 columns instead of 14)
#     Line #171 (got 23 columns instead of 14)
#     Line #172 (got 52 columns instead of 14)
#     Line #173 (got 18 columns instead of 14)
#     Line #174 (got 29 columns instead of 14)
#     Line #176 (got 26 columns instead of 14)
#     Line #177 (got 23 columns instead of 14)
#     Line #178 (got 23 columns instead of 14)
#     Line #179 (got 25 columns instead of 14)
#     Line #180 (got 22 columns instead of 14)
#     Line #181 (got 22 columns instead of 14)
#     Line #182 (got 24 columns instead of 14)
#     Line #183 (got 15 columns instead of 14)
#     Line #184 (got 23 columns instead of 14)
#     Line #185 (got 23 columns instead of 14)
#     Line #187 (got 17 columns instead of 14)
#     Line #188 (got 25 columns instead of 14)
#     Line #190 (got 23 columns instead of 14)
#     Line #191 (got 21 columns instead of 14)
#     Line #192 (got 18 columns instead of 14)
#     Line #193 (got 30 columns instead of 14)
#     Line #194 (got 22 columns instead of 14)
#     Line #195 (got 18 columns instead of 14)
#     Line #196 (got 24 columns instead of 14)
#     Line #197 (got 24 columns instead of 14)
#     Line #198 (got 23 columns instead of 14)
#     Line #199 (got 26 columns instead of 14)
#     Line #200 (got 32 columns instead of 14)
#     Line #201 (got 23 columns instead of 14)
#     Line #202 (got 22 columns instead of 14)
#     Line #203 (got 26 columns instead of 14)
#     Line #204 (got 21 columns instead of 14)
#     Line #205 (got 24 columns instead of 14)
#     Line #206 (got 22 columns instead of 14)
#     Line #207 (got 22 columns instead of 14)
#     Line #208 (got 22 columns instead of 14)
#     Line #209 (got 21 columns instead of 14)
#     Line #210 (got 23 columns instead of 14)
#     Line #211 (got 25 columns instead of 14)
#     Line #212 (got 20 columns instead of 14)
#     Line #213 (got 21 columns instead of 14)
#     Line #214 (got 27 columns instead of 14)
#     Line #215 (got 26 columns instead of 14)
#     Line #216 (got 27 columns instead of 14)
#     Line #217 (got 29 columns instead of 14)
#     Line #218 (got 26 columns instead of 14)
#     Line #219 (got 22 columns instead of 14)
#     Line #220 (got 16 columns instead of 14)
#     Line #221 (got 23 columns instead of 14)
#     Line #222 (got 22 columns instead of 14)
#     Line #224 (got 30 columns instead of 14)
#     Line #225 (got 17 columns instead of 14)
#     Line #226 (got 15 columns instead of 14)
#     Line #227 (got 26 columns instead of 14)
#     Line #228 (got 25 columns instead of 14)
#     Line #229 (got 18 columns instead of 14)
#     Line #230 (got 24 columns instead of 14)
#     Line #231 (got 17 columns instead of 14)
#     Line #232 (got 15 columns instead of 14)
#     Line #233 (got 20 columns instead of 14)
#     Line #234 (got 16 columns instead of 14)
#     Line #237 (got 15 columns instead of 14)
#     Line #238 (got 22 columns instead of 14)
#     Line #239 (got 22 columns instead of 14)
#     Line #240 (got 22 columns instead of 14)
#     Line #241 (got 22 columns instead of 14)
#     Line #242 (got 27 columns instead of 14)
#     Line #243 (got 23 columns instead of 14)
#     Line #244 (got 16 columns instead of 14)
#     Line #245 (got 19 columns instead of 14)
#     Line #246 (got 25 columns instead of 14)
#     Line #247 (got 16 columns instead of 14)
#     Line #248 (got 22 columns instead of 14)
#     Line #249 (got 23 columns instead of 14)
#     Line #250 (got 21 columns instead of 14)
#     Line #251 (got 27 columns instead of 14)
#     Line #252 (got 24 columns instead of 14)
#     Line #253 (got 24 columns instead of 14)
#     Line #254 (got 23 columns instead of 14)
#     Line #255 (got 19 columns instead of 14)
#     Line #256 (got 25 columns instead of 14)
#     Line #258 (got 26 columns instead of 14)
#     Line #259 (got 24 columns instead of 14)
#     Line #260 (got 24 columns instead of 14)
#     Line #261 (got 24 columns instead of 14)
#     Line #262 (got 26 columns instead of 14)
#     Line #263 (got 24 columns instead of 14)
#     Line #264 (got 17 columns instead of 14)
#     Line #265 (got 13 columns instead of 14)
#     Line #266 (got 28 columns instead of 14)
#     Line #267 (got 23 columns instead of 14)
#     Line #268 (got 15 columns instead of 14)
#     Line #269 (got 27 columns instead of 14)
#     Line #270 (got 25 columns instead of 14)
#     Line #271 (got 26 columns instead of 14)
#     Line #272 (got 21 columns instead of 14)
#     Line #273 (got 23 columns instead of 14)
#     Line #274 (got 18 columns instead of 14)
#     Line #275 (got 20 columns instead of 14)
#     Line #276 (got 23 columns instead of 14)
#     Line #277 (got 30 columns instead of 14)
#     Line #278 (got 21 columns instead of 14)
#     Line #279 (got 22 columns instead of 14)
#     Line #281 (got 24 columns instead of 14)
#     Line #282 (got 13 columns instead of 14)
#     Line #283 (got 24 columns instead of 14)
#     Line #284 (got 30 columns instead of 14)
#     Line #285 (got 16 columns instead of 14)
#     Line #286 (got 23 columns instead of 14)
#     Line #287 (got 24 columns instead of 14)
#     Line #288 (got 23 columns instead of 14)
#     Line #289 (got 24 columns instead of 14)
#     Line #290 (got 26 columns instead of 14)
#     Line #291 (got 23 columns instead of 14)
#     Line #292 (got 15 columns instead of 14)
#     Line #293 (got 37 columns instead of 14)
#     Line #294 (got 25 columns instead of 14)
#     Line #295 (got 26 columns instead of 14)
#     Line #296 (got 31 columns instead of 14)
#     Line #297 (got 21 columns instead of 14)
#     Line #298 (got 22 columns instead of 14)
#     Line #299 (got 43 columns instead of 14)
#     Line #300 (got 28 columns instead of 14)
#     Line #301 (got 24 columns instead of 14)
#     Line #302 (got 23 columns instead of 14)
#     Line #303 (got 21 columns instead of 14)
#     Line #304 (got 16 columns instead of 14)
#     Line #305 (got 24 columns instead of 14)
#     Line #306 (got 13 columns instead of 14)
#     Line #307 (got 26 columns instead of 14)
#     Line #308 (got 27 columns instead of 14)
#     Line #309 (got 24 columns instead of 14)
#     Line #311 (got 18 columns instead of 14)
#     Line #313 (got 40 columns instead of 14)
#     Line #315 (got 20 columns instead of 14)
#     Line #316 (got 22 columns instead of 14)
#     Line #317 (got 25 columns instead of 14)
#     Line #318 (got 22 columns instead of 14)
#     Line #320 (got 15 columns instead of 14)
#     Line #321 (got 24 columns instead of 14)
#     Line #322 (got 15 columns instead of 14)
#     Line #323 (got 21 columns instead of 14)
#     Line #324 (got 21 columns instead of 14)
#     Line #325 (got 26 columns instead of 14)
#     Line #326 (got 21 columns instead of 14)
#     Line #327 (got 26 columns instead of 14)
#     Line #328 (got 21 columns instead of 14)
#     Line #329 (got 23 columns instead of 14)
#     Line #330 (got 22 columns instead of 14)
#     Line #331 (got 24 columns instead of 14)
#     Line #332 (got 27 columns instead of 14)
#     Line #333 (got 22 columns instead of 14)
#     Line #334 (got 25 columns instead of 14)
#     Line #335 (got 27 columns instead of 14)
#     Line #336 (got 22 columns instead of 14)
#     Line #337 (got 25 columns instead of 14)
#     Line #338 (got 28 columns instead of 14)
#     Line #339 (got 31 columns instead of 14)
#     Line #340 (got 19 columns instead of 14)
#     Line #341 (got 20 columns instead of 14)
#     Line #342 (got 27 columns instead of 14)
#     Line #343 (got 30 columns instead of 14)
#     Line #344 (got 21 columns instead of 14)
#     Line #345 (got 22 columns instead of 14)
#     Line #346 (got 21 columns instead of 14)
#     Line #347 (got 27 columns instead of 14)
#     Line #348 (got 24 columns instead of 14)
#     Line #349 (got 25 columns instead of 14)
#     Line #350 (got 21 columns instead of 14)
#     Line #351 (got 28 columns instead of 14)
#     Line #352 (got 26 columns instead of 14)
#     Line #353 (got 26 columns instead of 14)
#     Line #354 (got 22 columns instead of 14)
#     Line #355 (got 20 columns instead of 14)
#     Line #356 (got 21 columns instead of 14)
#     Line #357 (got 23 columns instead of 14)
#     Line #358 (got 24 columns instead of 14)
#     Line #359 (got 30 columns instead of 14)
#     Line #360 (got 23 columns instead of 14)
#     Line #361 (got 18 columns instead of 14)
#     Line #362 (got 32 columns instead of 14)
#     Line #363 (got 22 columns instead of 14)
#     Line #364 (got 23 columns instead of 14)
#     Line #365 (got 24 columns instead of 14)
#     Line #366 (got 22 columns instead of 14)
#     Line #367 (got 25 columns instead of 14)
#     Line #368 (got 16 columns instead of 14)
#     Line #369 (got 27 columns instead of 14)
#     Line #371 (got 16 columns instead of 14)
#     Line #372 (got 24 columns instead of 14)
#     Line #373 (got 28 columns instead of 14)
#     Line #374 (got 22 columns instead of 14)
#     Line #375 (got 24 columns instead of 14)
#     Line #376 (got 21 columns instead of 14)
#     Line #377 (got 25 columns instead of 14)
#     Line #378 (got 25 columns instead of 14)
#     Line #379 (got 25 columns instead of 14)
#     Line #382 (got 25 columns instead of 14)
#     Line #383 (got 35 columns instead of 14)
#     Line #384 (got 25 columns instead of 14)
#     Line #385 (got 24 columns instead of 14)
#     Line #386 (got 19 columns instead of 14)
#     Line #387 (got 23 columns instead of 14)
#     Line #388 (got 23 columns instead of 14)
#     Line #389 (got 21 columns instead of 14)
#     Line #390 (got 17 columns instead of 14)
#     Line #391 (got 24 columns instead of 14)
#     Line #392 (got 31 columns instead of 14)
#     Line #393 (got 23 columns instead of 14)
#     Line #394 (got 30 columns instead of 14)
#     Line #395 (got 25 columns instead of 14)
#     Line #396 (got 26 columns instead of 14)
#     Line #397 (got 21 columns instead of 14)
#     Line #398 (got 25 columns instead of 14)
#     Line #399 (got 26 columns instead of 14)
#     Line #400 (got 20 columns instead of 14)
#     Line #401 (got 35 columns instead of 14)
#     Line #402 (got 26 columns instead of 14)
#     Line #403 (got 28 columns instead of 14)
#     Line #404 (got 27 columns instead of 14)
#     Line #406 (got 15 columns instead of 14)
#     Line #407 (got 18 columns instead of 14)
#     Line #408 (got 20 columns instead of 14)
#     Line #409 (got 20 columns instead of 14)
#     Line #410 (got 19 columns instead of 14)
#     Line #411 (got 19 columns instead of 14)
#     Line #412 (got 20 columns instead of 14)
#     Line #413 (got 21 columns instead of 14)
#     Line #414 (got 21 columns instead of 14)
#     Line #415 (got 20 columns instead of 14)
#     Line #416 (got 20 columns instead of 14)
#     Line #417 (got 20 columns instead of 14)
#     Line #418 (got 20 columns instead of 14)
#     Line #419 (got 18 columns instead of 14)
#     Line #420 (got 24 columns instead of 14)
#     Line #421 (got 20 columns instead of 14)
#     Line #422 (got 19 columns instead of 14)
#     Line #423 (got 21 columns instead of 14)
#     Line #424 (got 19 columns instead of 14)
#     Line #425 (got 20 columns instead of 14)
#     Line #426 (got 19 columns instead of 14)
#     Line #427 (got 19 columns instead of 14)
#     Line #428 (got 22 columns instead of 14)
#     Line #429 (got 25 columns instead of 14)
#     Line #430 (got 28 columns instead of 14)
#     Line #431 (got 26 columns instead of 14)
#     Line #432 (got 16 columns instead of 14)
#     Line #433 (got 17 columns instead of 14)
#     Line #434 (got 36 columns instead of 14)
#     Line #435 (got 19 columns instead of 14)
#     Line #436 (got 27 columns instead of 14)
#     Line #437 (got 24 columns instead of 14)
#     Line #438 (got 28 columns instead of 14)
#     Line #439 (got 25 columns instead of 14)
#     Line #440 (got 24 columns instead of 14)
#     Line #441 (got 28 columns instead of 14)
#     Line #442 (got 16 columns instead of 14)
#     Line #443 (got 28 columns instead of 14)
#     Line #444 (got 20 columns instead of 14)
#     Line #445 (got 28 columns instead of 14)
#     Line #446 (got 13 columns instead of 14)
#     Line #447 (got 24 columns instead of 14)
#     Line #448 (got 23 columns instead of 14)
#     Line #449 (got 24 columns instead of 14)
#     Line #450 (got 24 columns instead of 14)
#     Line #451 (got 26 columns instead of 14)
#     Line #452 (got 28 columns instead of 14)
#     Line #453 (got 28 columns instead of 14)
#     Line #454 (got 31 columns instead of 14)
#     Line #455 (got 37 columns instead of 14)
#     Line #456 (got 19 columns instead of 14)
#     Line #457 (got 15 columns instead of 14)
#     Line #458 (got 25 columns instead of 14)
#     Line #459 (got 18 columns instead of 14)
#     Line #460 (got 23 columns instead of 14)
#     Line #461 (got 30 columns instead of 14)
#     Line #462 (got 26 columns instead of 14)
#     Line #463 (got 28 columns instead of 14)
#     Line #464 (got 13 columns instead of 14)
#     Line #465 (got 24 columns instead of 14)
#     Line #466 (got 25 columns instead of 14)
#     Line #468 (got 15 columns instead of 14)
#     Line #470 (got 24 columns instead of 14)
#     Line #471 (got 23 columns instead of 14)
#     Line #472 (got 16 columns instead of 14)
#     Line #473 (got 27 columns instead of 14)
#     Line #474 (got 19 columns instead of 14)
#     Line #475 (got 16 columns instead of 14)
#     Line #476 (got 26 columns instead of 14)
#     Line #477 (got 21 columns instead of 14)
#     Line #478 (got 23 columns instead of 14)
#     Line #479 (got 23 columns instead of 14)
#     Line #480 (got 21 columns instead of 14)
#     Line #481 (got 26 columns instead of 14)
#     Line #482 (got 27 columns instead of 14)
#     Line #483 (got 25 columns instead of 14)
#     Line #485 (got 25 columns instead of 14)
#     Line #487 (got 17 columns instead of 14)
#     Line #488 (got 28 columns instead of 14)
#     Line #489 (got 28 columns instead of 14)
#     Line #490 (got 21 columns instead of 14)
#     Line #491 (got 25 columns instead of 14)
#     Line #492 (got 16 columns instead of 14)
#     Line #493 (got 28 columns instead of 14)
#     Line #494 (got 25 columns instead of 14)
#     Line #495 (got 32 columns instead of 14)
#     Line #496 (got 24 columns instead of 14)
#     Line #498 (got 26 columns instead of 14)
#     Line #499 (got 15 columns instead of 14)
#     Line #500 (got 24 columns instead of 14)
#     Line #502 (got 26 columns instead of 14)
#     Line #503 (got 24 columns instead of 14)
#     Line #504 (got 21 columns instead of 14)
#     Line #505 (got 26 columns instead of 14)
#     Line #506 (got 27 columns instead of 14)
#     Line #507 (got 24 columns instead of 14)
#     Line #508 (got 17 columns instead of 14)
#     Line #509 (got 24 columns instead of 14)
#     Line #510 (got 20 columns instead of 14)
#     Line #511 (got 19 columns instead of 14)
#     Line #512 (got 34 columns instead of 14)
#     Line #513 (got 17 columns instead of 14)
#     Line #514 (got 21 columns instead of 14)
#     Line #515 (got 22 columns instead of 14)
#     Line #516 (got 22 columns instead of 14)
#     Line #517 (got 25 columns instead of 14)
#     Line #518 (got 33 columns instead of 14)
#     Line #519 (got 31 columns instead of 14)
#     Line #520 (got 22 columns instead of 14)
#     Line #521 (got 15 columns instead of 14)
#     Line #522 (got 20 columns instead of 14)
#     Line #523 (got 21 columns instead of 14)
#     Line #524 (got 15 columns instead of 14)
#     Line #525 (got 34 columns instead of 14)
#     Line #526 (got 41 columns instead of 14)
#     Line #527 (got 20 columns instead of 14)
#     Line #528 (got 38 columns instead of 14)
#     Line #529 (got 23 columns instead of 14)
#     Line #530 (got 25 columns instead of 14)
#     Line #531 (got 21 columns instead of 14)
#     Line #532 (got 20 columns instead of 14)
#     Line #533 (got 24 columns instead of 14)
#     Line #534 (got 27 columns instead of 14)
#     Line #535 (got 24 columns instead of 14)
#     Line #536 (got 21 columns instead of 14)
#     Line #537 (got 20 columns instead of 14)
#     Line #538 (got 25 columns instead of 14)
#     Line #539 (got 20 columns instead of 14)
#     Line #540 (got 29 columns instead of 14)
#     Line #541 (got 22 columns instead of 14)
#     Line #542 (got 24 columns instead of 14)
#     Line #543 (got 22 columns instead of 14)
#     Line #544 (got 20 columns instead of 14)
#     Line #545 (got 23 columns instead of 14)
#     Line #546 (got 26 columns instead of 14)
#     Line #547 (got 20 columns instead of 14)
#     Line #548 (got 35 columns instead of 14)
#     Line #549 (got 29 columns instead of 14)
#     Line #550 (got 28 columns instead of 14)
#     Line #552 (got 24 columns instead of 14)
#     Line #553 (got 22 columns instead of 14)
#     Line #554 (got 23 columns instead of 14)
#     Line #555 (got 26 columns instead of 14)
#     Line #556 (got 27 columns instead of 14)
#     Line #557 (got 28 columns instead of 14)
#     Line #558 (got 22 columns instead of 14)
#     Line #559 (got 24 columns instead of 14)
#     Line #560 (got 22 columns instead of 14)
#     Line #561 (got 29 columns instead of 14)
#     Line #562 (got 15 columns instead of 14)
#     Line #563 (got 23 columns instead of 14)
#     Line #564 (got 24 columns instead of 14)
#     Line #565 (got 25 columns instead of 14)
#     Line #566 (got 24 columns instead of 14)
#     Line #567 (got 23 columns instead of 14)
#     Line #568 (got 26 columns instead of 14)
#     Line #569 (got 24 columns instead of 14)
#     Line #570 (got 21 columns instead of 14)
#     Line #571 (got 27 columns instead of 14)
#     Line #572 (got 24 columns instead of 14)
#     Line #573 (got 29 columns instead of 14)
#     Line #574 (got 21 columns instead of 14)
#     Line #575 (got 26 columns instead of 14)
#     Line #576 (got 25 columns instead of 14)
#     Line #577 (got 25 columns instead of 14)
#     Line #578 (got 32 columns instead of 14)
#     Line #579 (got 24 columns instead of 14)
#     Line #580 (got 28 columns instead of 14)
#     Line #581 (got 25 columns instead of 14)
#     Line #582 (got 19 columns instead of 14)
#     Line #583 (got 23 columns instead of 14)
#     Line #584 (got 29 columns instead of 14)
#     Line #585 (got 25 columns instead of 14)
#     Line #586 (got 27 columns instead of 14)
#     Line #587 (got 23 columns instead of 14)
#     Line #588 (got 26 columns instead of 14)
#     Line #589 (got 31 columns instead of 14)
#     Line #590 (got 18 columns instead of 14)
#     Line #591 (got 24 columns instead of 14)
#     Line #592 (got 22 columns instead of 14)
#     Line #593 (got 28 columns instead of 14)
#     Line #594 (got 25 columns instead of 14)
#     Line #595 (got 26 columns instead of 14)
#     Line #596 (got 27 columns instead of 14)
#     Line #597 (got 20 columns instead of 14)
#     Line #598 (got 22 columns instead of 14)
#     Line #599 (got 25 columns instead of 14)
#     Line #600 (got 24 columns instead of 14)
#     Line #601 (got 24 columns instead of 14)
#     Line #602 (got 20 columns instead of 14)
#     Line #603 (got 23 columns instead of 14)
#     Line #604 (got 27 columns instead of 14)
#     Line #605 (got 22 columns instead of 14)
#     Line #606 (got 26 columns instead of 14)
#     Line #607 (got 32 columns instead of 14)
#     Line #608 (got 25 columns instead of 14)
#     Line #609 (got 23 columns instead of 14)
#     Line #610 (got 28 columns instead of 14)
#     Line #611 (got 26 columns instead of 14)
#     Line #612 (got 27 columns instead of 14)
#     Line #613 (got 28 columns instead of 14)
#     Line #614 (got 29 columns instead of 14)
#     Line #615 (got 28 columns instead of 14)
#     Line #616 (got 31 columns instead of 14)
#     Line #617 (got 23 columns instead of 14)
#     Line #618 (got 22 columns instead of 14)
#     Line #619 (got 22 columns instead of 14)
#     Line #620 (got 23 columns instead of 14)
#     Line #621 (got 23 columns instead of 14)
#     Line #622 (got 13 columns instead of 14)
#     Line #623 (got 18 columns instead of 14)
#     Line #624 (got 23 columns instead of 14)
#     Line #625 (got 19 columns instead of 14)
#     Line #626 (got 25 columns instead of 14)
#     Line #627 (got 36 columns instead of 14)
#     Line #628 (got 15 columns instead of 14)
#     Line #629 (got 18 columns instead of 14)
#     Line #630 (got 21 columns instead of 14)
#     Line #631 (got 24 columns instead of 14)
#     Line #632 (got 24 columns instead of 14)
#     Line #633 (got 22 columns instead of 14)
#     Line #634 (got 22 columns instead of 14)
#     Line #635 (got 17 columns instead of 14)
#     Line #637 (got 24 columns instead of 14)
#     Line #638 (got 23 columns instead of 14)
#     Line #639 (got 36 columns instead of 14)
#     Line #640 (got 17 columns instead of 14)
#     Line #641 (got 32 columns instead of 14)
#     Line #642 (got 26 columns instead of 14)
#     Line #644 (got 30 columns instead of 14)
#     Line #645 (got 20 columns instead of 14)
#     Line #646 (got 26 columns instead of 14)
#     Line #647 (got 17 columns instead of 14)
#     Line #648 (got 32 columns instead of 14)
#     Line #649 (got 18 columns instead of 14)
#     Line #650 (got 17 columns instead of 14)
#     Line #651 (got 25 columns instead of 14)
#     Line #652 (got 17 columns instead of 14)
#     Line #653 (got 29 columns instead of 14)
#     Line #654 (got 27 columns instead of 14)
#     Line #655 (got 16 columns instead of 14)
#     Line #656 (got 3 columns instead of 14)
#     Line #657 (got 3 columns instead of 14)
#     Line #658 (got 19 columns instead of 14)
#     Line #659 (got 16 columns instead of 14)
#     Line #660 (got 20 columns instead of 14)
#     Line #661 (got 29 columns instead of 14)
#     Line #662 (got 22 columns instead of 14)
#     Line #663 (got 28 columns instead of 14)
#     Line #664 (got 23 columns instead of 14)
#     Line #665 (got 24 columns instead of 14)
#     Line #666 (got 13 columns instead of 14)
#     Line #667 (got 25 columns instead of 14)
#     Line #668 (got 25 columns instead of 14)
#     Line #669 (got 29 columns instead of 14)
#     Line #670 (got 24 columns instead of 14)
#     Line #671 (got 33 columns instead of 14)
#     Line #672 (got 26 columns instead of 14)
#     Line #673 (got 26 columns instead of 14)
#     Line #674 (got 28 columns instead of 14)
#     Line #675 (got 18 columns instead of 14)
#     Line #676 (got 25 columns instead of 14)
#     Line #677 (got 18 columns instead of 14)
#     Line #678 (got 40 columns instead of 14)
#     Line #679 (got 24 columns instead of 14)
#     Line #680 (got 21 columns instead of 14)
#     Line #681 (got 25 columns instead of 14)
#     Line #682 (got 16 columns instead of 14)
#     Line #683 (got 29 columns instead of 14)
#     Line #684 (got 19 columns instead of 14)
#     Line #685 (got 28 columns instead of 14)
#     Line #686 (got 26 columns instead of 14)
#     Line #687 (got 22 columns instead of 14)
#     Line #688 (got 24 columns instead of 14)
#     Line #689 (got 21 columns instead of 14)
#     Line #690 (got 24 columns instead of 14)
#     Line #691 (got 26 columns instead of 14)
#     Line #692 (got 25 columns instead of 14)
#     Line #693 (got 22 columns instead of 14)
#     Line #694 (got 25 columns instead of 14)
#     Line #695 (got 25 columns instead of 14)
#     Line #696 (got 18 columns instead of 14)
#     Line #697 (got 17 columns instead of 14)
#     Line #698 (got 27 columns instead of 14)
#     Line #699 (got 17 columns instead of 14)
#     Line #700 (got 16 columns instead of 14)
#     Line #701 (got 21 columns instead of 14)
#     Line #702 (got 31 columns instead of 14)
#     Line #703 (got 21 columns instead of 14)
#     Line #704 (got 25 columns instead of 14)
#     Line #705 (got 24 columns instead of 14)
#     Line #706 (got 24 columns instead of 14)
#     Line #707 (got 17 columns instead of 14)
#     Line #708 (got 23 columns instead of 14)
#     Line #709 (got 24 columns instead of 14)
#     Line #710 (got 22 columns instead of 14)
#     Line #711 (got 26 columns instead of 14)
#     Line #712 (got 16 columns instead of 14)
#     Line #713 (got 26 columns instead of 14)
#     Line #714 (got 22 columns instead of 14)
#     Line #715 (got 22 columns instead of 14)
#     Line #716 (got 21 columns instead of 14)
#     Line #717 (got 19 columns instead of 14)
#     Line #718 (got 20 columns instead of 14)
#     Line #719 (got 20 columns instead of 14)
#     Line #720 (got 24 columns instead of 14)
#     Line #721 (got 20 columns instead of 14)
#     Line #722 (got 16 columns instead of 14)
#     Line #723 (got 23 columns instead of 14)
#     Line #724 (got 13 columns instead of 14)
#     Line #727 (got 18 columns instead of 14)
#     Line #728 (got 18 columns instead of 14)
#     Line #729 (got 15 columns instead of 14)
#     Line #730 (got 20 columns instead of 14)
#     Line #731 (got 16 columns instead of 14)
#     Line #732 (got 17 columns instead of 14)
#     Line #733 (got 34 columns instead of 14)
#     Line #734 (got 15 columns instead of 14)
#     Line #735 (got 24 columns instead of 14)
#     Line #736 (got 26 columns instead of 14)
#     Line #737 (got 19 columns instead of 14)
#     Line #738 (got 27 columns instead of 14)
#     Line #739 (got 27 columns instead of 14)
#     Line #740 (got 15 columns instead of 14)
#     Line #741 (got 22 columns instead of 14)
#     Line #742 (got 26 columns instead of 14)
#     Line #743 (got 24 columns instead of 14)
#     Line #744 (got 22 columns instead of 14)
#     Line #745 (got 25 columns instead of 14)
#     Line #746 (got 18 columns instead of 14)
#     Line #747 (got 21 columns instead of 14)
#     Line #748 (got 23 columns instead of 14)
#     Line #749 (got 24 columns instead of 14)
#     Line #750 (got 16 columns instead of 14)
#     Line #751 (got 17 columns instead of 14)
#     Line #752 (got 26 columns instead of 14)
#     Line #754 (got 23 columns instead of 14)
#     Line #755 (got 26 columns instead of 14)
#     Line #756 (got 26 columns instead of 14)
#     Line #757 (got 16 columns instead of 14)
#     Line #758 (got 24 columns instead of 14)
#     Line #760 (got 28 columns instead of 14)
#     Line #761 (got 16 columns instead of 14)
#     Line #762 (got 15 columns instead of 14)
#     Line #764 (got 18 columns instead of 14)
#     Line #765 (got 25 columns instead of 14)
#     Line #766 (got 23 columns instead of 14)
#     Line #767 (got 25 columns instead of 14)
#     Line #768 (got 15 columns instead of 14)
#     Line #769 (got 25 columns instead of 14)
#     Line #770 (got 26 columns instead of 14)
#     Line #771 (got 16 columns instead of 14)
#     Line #772 (got 16 columns instead of 14)
#     Line #773 (got 30 columns instead of 14)
#     Line #774 (got 21 columns instead of 14)
#     Line #775 (got 25 columns instead of 14)
#     Line #776 (got 21 columns instead of 14)
#     Line #777 (got 26 columns instead of 14)
#     Line #778 (got 28 columns instead of 14)
#     Line #779 (got 26 columns instead of 14)
#     Line #780 (got 33 columns instead of 14)
#     Line #781 (got 26 columns instead of 14)
#     Line #782 (got 22 columns instead of 14)
#     Line #783 (got 13 columns instead of 14)
#     Line #784 (got 25 columns instead of 14)
#     Line #785 (got 26 columns instead of 14)
#     Line #786 (got 25 columns instead of 14)
#     Line #787 (got 15 columns instead of 14)
#     Line #788 (got 24 columns instead of 14)
#     Line #789 (got 23 columns instead of 14)
#     Line #790 (got 21 columns instead of 14)
#     Line #791 (got 40 columns instead of 14)
#     Line #793 (got 45 columns instead of 14)
#     Line #794 (got 26 columns instead of 14)
#     Line #795 (got 25 columns instead of 14)
#     Line #796 (got 25 columns instead of 14)
#     Line #797 (got 21 columns instead of 14)
#     Line #798 (got 24 columns instead of 14)
#     Line #799 (got 24 columns instead of 14)
#     Line #800 (got 22 columns instead of 14)
#     Line #801 (got 24 columns instead of 14)
#     Line #802 (got 25 columns instead of 14)
#     Line #803 (got 24 columns instead of 14)
#     Line #804 (got 24 columns instead of 14)
#     Line #805 (got 22 columns instead of 14)
#     Line #806 (got 28 columns instead of 14)
#     Line #807 (got 22 columns instead of 14)
#     Line #808 (got 23 columns instead of 14)
#     Line #809 (got 23 columns instead of 14)
#     Line #810 (got 24 columns instead of 14)
#     Line #811 (got 23 columns instead of 14)
#     Line #812 (got 26 columns instead of 14)
#     Line #813 (got 26 columns instead of 14)
#     Line #814 (got 23 columns instead of 14)
#     Line #815 (got 16 columns instead of 14)
#     Line #816 (got 23 columns instead of 14)
#     Line #817 (got 26 columns instead of 14)
#     Line #818 (got 26 columns instead of 14)
#     Line #819 (got 25 columns instead of 14)
#     Line #820 (got 29 columns instead of 14)
#     Line #821 (got 25 columns instead of 14)
#     Line #822 (got 28 columns instead of 14)
#     Line #823 (got 18 columns instead of 14)
#     Line #824 (got 18 columns instead of 14)
#     Line #825 (got 22 columns instead of 14)
#     Line #826 (got 18 columns instead of 14)
#     Line #827 (got 23 columns instead of 14)
#     Line #828 (got 15 columns instead of 14)
#     Line #829 (got 23 columns instead of 14)
#     Line #830 (got 22 columns instead of 14)
#     Line #831 (got 23 columns instead of 14)
#     Line #832 (got 27 columns instead of 14)
#     Line #833 (got 17 columns instead of 14)
#     Line #834 (got 26 columns instead of 14)
#     Line #835 (got 31 columns instead of 14)
#     Line #836 (got 27 columns instead of 14)
#     Line #837 (got 28 columns instead of 14)
#     Line #838 (got 25 columns instead of 14)
#     Line #839 (got 26 columns instead of 14)
#     Line #840 (got 15 columns instead of 14)
#     Line #841 (got 32 columns instead of 14)
#     Line #842 (got 26 columns instead of 14)
#     Line #843 (got 26 columns instead of 14)
#     Line #845 (got 37 columns instead of 14)
#     Line #846 (got 16 columns instead of 14)
#     Line #847 (got 24 columns instead of 14)
#     Line #848 (got 22 columns instead of 14)
#     Line #849 (got 22 columns instead of 14)
#     Line #850 (got 22 columns instead of 14)
#     Line #851 (got 15 columns instead of 14)
#     Line #852 (got 25 columns instead of 14)
#     Line #853 (got 16 columns instead of 14)
#     Line #854 (got 16 columns instead of 14)
#     Line #855 (got 29 columns instead of 14)
#     Line #857 (got 22 columns instead of 14)
#     Line #858 (got 21 columns instead of 14)
#     Line #859 (got 18 columns instead of 14)
#     Line #860 (got 25 columns instead of 14)
#     Line #861 (got 25 columns instead of 14)
#     Line #862 (got 15 columns instead of 14)
#     Line #863 (got 20 columns instead of 14)
#     Line #864 (got 18 columns instead of 14)
#     Line #865 (got 22 columns instead of 14)
#     Line #866 (got 23 columns instead of 14)
#     Line #867 (got 26 columns instead of 14)
#     Line #868 (got 27 columns instead of 14)
#     Line #869 (got 13 columns instead of 14)
#     Line #870 (got 24 columns instead of 14)
#     Line #871 (got 32 columns instead of 14)
#     Line #873 (got 27 columns instead of 14)
#     Line #874 (got 26 columns instead of 14)
#     Line #875 (got 25 columns instead of 14)
#     Line #876 (got 17 columns instead of 14)
#     Line #877 (got 24 columns instead of 14)
#     Line #878 (got 15 columns instead of 14)
#     Line #879 (got 22 columns instead of 14)
#     Line #880 (got 23 columns instead of 14)
#     Line #881 (got 26 columns instead of 14)
#     Line #882 (got 17 columns instead of 14)
#     Line #883 (got 19 columns instead of 14)
#     Line #884 (got 24 columns instead of 14)
#     Line #885 (got 56 columns instead of 14)
#     Line #886 (got 20 columns instead of 14)
#     Line #887 (got 25 columns instead of 14)
#     Line #888 (got 26 columns instead of 14)
#     Line #889 (got 27 columns instead of 14)
#     Line #890 (got 19 columns instead of 14)
#     Line #891 (got 24 columns instead of 14)
#     Line #892 (got 21 columns instead of 14)
#     Line #893 (got 26 columns instead of 14)
#     Line #894 (got 20 columns instead of 14)
#     Line #895 (got 24 columns instead of 14)
#     Line #896 (got 20 columns instead of 14)
#     Line #897 (got 19 columns instead of 14)
#     Line #898 (got 21 columns instead of 14)
#     Line #899 (got 24 columns instead of 14)
#     Line #900 (got 26 columns instead of 14)
#     Line #901 (got 23 columns instead of 14)
#     Line #902 (got 17 columns instead of 14)
#     Line #903 (got 22 columns instead of 14)
#     Line #904 (got 22 columns instead of 14)
#     Line #905 (got 22 columns instead of 14)
#     Line #906 (got 24 columns instead of 14)
#     Line #907 (got 21 columns instead of 14)
#     Line #908 (got 21 columns instead of 14)
#     Line #909 (got 13 columns instead of 14)
#     Line #910 (got 25 columns instead of 14)
#     Line #911 (got 24 columns instead of 14)
#     Line #912 (got 23 columns instead of 14)
#     Line #913 (got 16 columns instead of 14)
#     Line #914 (got 16 columns instead of 14)
#     Line #915 (got 23 columns instead of 14)
#     Line #916 (got 17 columns instead of 14)
#     Line #917 (got 25 columns instead of 14)
#     Line #918 (got 20 columns instead of 14)
#     Line #919 (got 26 columns instead of 14)
#     Line #921 (got 15 columns instead of 14)
#     Line #922 (got 26 columns instead of 14)
#     Line #923 (got 20 columns instead of 14)
#     Line #924 (got 22 columns instead of 14)
#     Line #925 (got 20 columns instead of 14)
#     Line #926 (got 24 columns instead of 14)
#     Line #927 (got 16 columns instead of 14)
#     Line #928 (got 20 columns instead of 14)
#     Line #929 (got 23 columns instead of 14)
#     Line #930 (got 21 columns instead of 14)
#     Line #931 (got 20 columns instead of 14)
#     Line #932 (got 23 columns instead of 14)
#     Line #933 (got 23 columns instead of 14)
#     Line #934 (got 26 columns instead of 14)
#     Line #935 (got 25 columns instead of 14)
#     Line #936 (got 25 columns instead of 14)
#     Line #937 (got 28 columns instead of 14)
#     Line #938 (got 13 columns instead of 14)
#     Line #939 (got 15 columns instead of 14)
#     Line #940 (got 16 columns instead of 14)
#     Line #941 (got 24 columns instead of 14)
#     Line #942 (got 18 columns instead of 14)
#     Line #943 (got 25 columns instead of 14)
#     Line #944 (got 25 columns instead of 14)
#     Line #945 (got 28 columns instead of 14)
#     Line #946 (got 16 columns instead of 14)
#     Line #947 (got 18 columns instead of 14)
#     Line #948 (got 24 columns instead of 14)
#     Line #949 (got 24 columns instead of 14)
#     Line #950 (got 24 columns instead of 14)
#     Line #951 (got 22 columns instead of 14)
#     Line #952 (got 27 columns instead of 14)
#     Line #953 (got 25 columns instead of 14)
#     Line #954 (got 23 columns instead of 14)
#     Line #955 (got 22 columns instead of 14)
#     Line #956 (got 21 columns instead of 14)
#     Line #957 (got 23 columns instead of 14)
#     Line #958 (got 29 columns instead of 14)
#     Line #959 (got 13 columns instead of 14)
#     Line #960 (got 28 columns instead of 14)
#     Line #961 (got 25 columns instead of 14)
#     Line #962 (got 27 columns instead of 14)
#     Line #963 (got 27 columns instead of 14)
#     Line #964 (got 20 columns instead of 14)
#     Line #965 (got 21 columns instead of 14)
#     Line #966 (got 25 columns instead of 14)
#     Line #967 (got 32 columns instead of 14)
#     Line #968 (got 24 columns instead of 14)
#     Line #969 (got 15 columns instead of 14)
#     Line #970 (got 22 columns instead of 14)
#     Line #971 (got 25 columns instead of 14)
#     Line #972 (got 24 columns instead of 14)
#     Line #973 (got 21 columns instead of 14)
#     Line #974 (got 25 columns instead of 14)
#     Line #975 (got 21 columns instead of 14)
#     Line #976 (got 23 columns instead of 14)
#     Line #977 (got 24 columns instead of 14)
#     Line #978 (got 24 columns instead of 14)
#     Line #979 (got 22 columns instead of 14)
#     Line #980 (got 18 columns instead of 14)
#     Line #981 (got 26 columns instead of 14)
#     Line #982 (got 21 columns instead of 14)
#     Line #983 (got 25 columns instead of 14)
#     Line #984 (got 23 columns instead of 14)
#     Line #985 (got 20 columns instead of 14)
#     Line #986 (got 21 columns instead of 14)
#     Line #987 (got 22 columns instead of 14)
#     Line #988 (got 20 columns instead of 14)
#     Line #989 (got 25 columns instead of 14)
#     Line #990 (got 22 columns instead of 14)
#     Line #991 (got 23 columns instead of 14)
#     Line #992 (got 18 columns instead of 14)
#     Line #993 (got 19 columns instead of 14)
#     Line #994 (got 15 columns instead of 14)
#     Line #995 (got 28 columns instead of 14)
#     Line #996 (got 25 columns instead of 14)
#     Line #997 (got 26 columns instead of 14)
#     Line #998 (got 19 columns instead of 14)
#     Line #999 (got 17 columns instead of 14)
#     Line #1001 (got 19 columns instead of 14)
#     Line #1002 (got 20 columns instead of 14)
#     Line #1003 (got 26 columns instead of 14)
#     Line #1004 (got 21 columns instead of 14)
#     Line #1005 (got 22 columns instead of 14)
#     Line #1006 (got 15 columns instead of 14)
#     Line #1007 (got 16 columns instead of 14)
#     Line #1008 (got 17 columns instead of 14)
#     Line #1009 (got 21 columns instead of 14)
#     Line #1010 (got 15 columns instead of 14)
#     Line #1011 (got 24 columns instead of 14)
#     Line #1012 (got 21 columns instead of 14)
#     Line #1013 (got 13 columns instead of 14)
#     Line #1014 (got 25 columns instead of 14)
#     Line #1015 (got 26 columns instead of 14)
#     Line #1016 (got 17 columns instead of 14)
#     Line #1017 (got 22 columns instead of 14)
#     Line #1018 (got 23 columns instead of 14)
#     Line #1019 (got 24 columns instead of 14)
#     Line #1020 (got 22 columns instead of 14)
#     Line #1021 (got 26 columns instead of 14)
#     Line #1022 (got 17 columns instead of 14)
#     Line #1023 (got 25 columns instead of 14)
#     Line #1024 (got 21 columns instead of 14)
#     Line #1025 (got 28 columns instead of 14)
#     Line #1026 (got 26 columns instead of 14)
#     Line #1027 (got 25 columns instead of 14)
#     Line #1028 (got 23 columns instead of 14)
#     Line #1029 (got 28 columns instead of 14)
#     Line #1030 (got 24 columns instead of 14)
#     Line #1031 (got 22 columns instead of 14)
#     Line #1032 (got 36 columns instead of 14)
#     Line #1033 (got 24 columns instead of 14)
#     Line #1034 (got 19 columns instead of 14)
#     Line #1035 (got 27 columns instead of 14)
#     Line #1036 (got 19 columns instead of 14)
#     Line #1037 (got 25 columns instead of 14)
#     Line #1038 (got 25 columns instead of 14)
#     Line #1039 (got 23 columns instead of 14)
#     Line #1040 (got 17 columns instead of 14)
#     Line #1041 (got 18 columns instead of 14)
#     Line #1042 (got 37 columns instead of 14)
#     Line #1043 (got 29 columns instead of 14)
#     Line #1045 (got 27 columns instead of 14)
#     Line #1046 (got 32 columns instead of 14)
#     Line #1047 (got 15 columns instead of 14)
#     Line #1048 (got 23 columns instead of 14)
#     Line #1049 (got 20 columns instead of 14)
#     Line #1050 (got 22 columns instead of 14)
#     Line #1051 (got 27 columns instead of 14)
#     Line #1052 (got 25 columns instead of 14)
#     Line #1053 (got 24 columns instead of 14)
#     Line #1054 (got 25 columns instead of 14)
#     Line #1055 (got 22 columns instead of 14)
#     Line #1056 (got 25 columns instead of 14)
#     Line #1057 (got 26 columns instead of 14)
#     Line #1058 (got 15 columns instead of 14)
#     Line #1059 (got 19 columns instead of 14)
#     Line #1060 (got 29 columns instead of 14)
#     Line #1061 (got 39 columns instead of 14)
#     Line #1062 (got 16 columns instead of 14)
#     Line #1064 (got 26 columns instead of 14)
#     Line #1065 (got 19 columns instead of 14)
#     Line #1066 (got 24 columns instead of 14)
#     Line #1067 (got 42 columns instead of 14)
#     Line #1068 (got 24 columns instead of 14)
#     Line #1069 (got 37 columns instead of 14)
#     Line #1070 (got 15 columns instead of 14)
#     Line #1071 (got 18 columns instead of 14)
#     Line #1072 (got 13 columns instead of 14)
#     Line #1073 (got 20 columns instead of 14)
#     Line #1074 (got 23 columns instead of 14)
#     Line #1075 (got 20 columns instead of 14)
#     Line #1077 (got 23 columns instead of 14)
#     Line #1079 (got 13 columns instead of 14)
#     Line #1081 (got 24 columns instead of 14)
#     Line #1082 (got 19 columns instead of 14)
#     Line #1083 (got 23 columns instead of 14)
#     Line #1084 (got 16 columns instead of 14)
#     Line #1085 (got 21 columns instead of 14)
#     Line #1086 (got 20 columns instead of 14)
#     Line #1087 (got 19 columns instead of 14)
#     Line #1088 (got 26 columns instead of 14)
#     Line #1089 (got 24 columns instead of 14)
#     Line #1090 (got 22 columns instead of 14)
#     Line #1091 (got 17 columns instead of 14)
#     Line #1092 (got 23 columns instead of 14)
#     Line #1093 (got 27 columns instead of 14)
#     Line #1094 (got 15 columns instead of 14)
# ...
#     Line #8448 (got 25 columns instead of 14)
#     Line #8449 (got 23 columns instead of 14)
#     Line #8450 (got 24 columns instead of 14)
#     Line #8451 (got 19 columns instead of 14)
#     Line #8452 (got 23 columns instead of 14)
#     Line #8453 (got 25 columns instead of 14)
#     Line #8454 (got 18 columns instead of 14)
#     Line #8455 (got 24 columns instead of 14)
#     Line #8456 (got 26 columns instead of 14)
#     Line #8457 (got 23 columns instead of 14)
#     Line #8458 (got 25 columns instead of 14)
#     Line #8459 (got 32 columns instead of 14)
#     Line #8460 (got 26 columns instead of 14)
#     Line #8461 (got 35 columns instead of 14)
#     Line #8462 (got 23 columns instead of 14)
#     Line #8463 (got 23 columns instead of 14)
#     Line #8464 (got 25 columns instead of 14)
#     Line #8465 (got 23 columns instead of 14)
#     Line #8466 (got 16 columns instead of 14)
#     Line #8467 (got 26 columns instead of 14)
#     Line #8468 (got 21 columns instead of 14)
#     Line #8469 (got 24 columns instead of 14)
#     Line #8470 (got 53 columns instead of 14)
#     Line #8471 (got 22 columns instead of 14)
#     Line #8472 (got 15 columns instead of 14)
#     Line #8473 (got 21 columns instead of 14)
#     Line #8474 (got 16 columns instead of 14)
#     Line #8476 (got 19 columns instead of 14)
#     Line #8477 (got 24 columns instead of 14)
#     Line #8478 (got 13 columns instead of 14)
#     Line #8479 (got 15 columns instead of 14)
#     Line #8480 (got 15 columns instead of 14)
#     Line #8481 (got 18 columns instead of 14)
#     Line #8482 (got 17 columns instead of 14)
#     Line #8483 (got 17 columns instead of 14)
#     Line #8484 (got 18 columns instead of 14)
#     Line #8485 (got 21 columns instead of 14)
#     Line #8486 (got 44 columns instead of 14)
#     Line #8487 (got 22 columns instead of 14)
#     Line #8488 (got 26 columns instead of 14)
#     Line #8489 (got 22 columns instead of 14)
#     Line #8490 (got 23 columns instead of 14)
#     Line #8491 (got 25 columns instead of 14)
#     Line #8492 (got 20 columns instead of 14)
#     Line #8493 (got 22 columns instead of 14)
#     Line #8494 (got 18 columns instead of 14)
#     Line #8495 (got 19 columns instead of 14)
#     Line #8496 (got 26 columns instead of 14)
#     Line #8497 (got 23 columns instead of 14)
#     Line #8498 (got 23 columns instead of 14)
#     Line #8499 (got 20 columns instead of 14)
#     Line #8500 (got 30 columns instead of 14)
#     Line #8501 (got 26 columns instead of 14)
#     Line #8502 (got 24 columns instead of 14)
#     Line #8503 (got 18 columns instead of 14)
#     Line #8504 (got 17 columns instead of 14)
#     Line #8505 (got 29 columns instead of 14)
#     Line #8508 (got 19 columns instead of 14)
#     Line #8509 (got 20 columns instead of 14)
#     Line #8510 (got 28 columns instead of 14)
#     Line #8511 (got 21 columns instead of 14)
#     Line #8512 (got 27 columns instead of 14)
#     Line #8513 (got 22 columns instead of 14)
#     Line #8514 (got 25 columns instead of 14)
#     Line #8515 (got 22 columns instead of 14)
#     Line #8516 (got 22 columns instead of 14)
#     Line #8517 (got 26 columns instead of 14)
#     Line #8518 (got 23 columns instead of 14)
#     Line #8519 (got 26 columns instead of 14)
#     Line #8520 (got 16 columns instead of 14)
#     Line #8521 (got 25 columns instead of 14)
#     Line #8523 (got 18 columns instead of 14)
#     Line #8524 (got 19 columns instead of 14)
#     Line #8525 (got 15 columns instead of 14)
#     Line #8526 (got 23 columns instead of 14)
#     Line #8527 (got 23 columns instead of 14)
#     Line #8528 (got 16 columns instead of 14)
#     Line #8529 (got 26 columns instead of 14)
#     Line #8530 (got 24 columns instead of 14)
#     Line #8531 (got 26 columns instead of 14)
#     Line #8532 (got 18 columns instead of 14)
#     Line #8533 (got 24 columns instead of 14)
#     Line #8535 (got 25 columns instead of 14)
#     Line #8536 (got 27 columns instead of 14)
#     Line #8537 (got 16 columns instead of 14)
#     Line #8538 (got 29 columns instead of 14)
#     Line #8539 (got 21 columns instead of 14)
#     Line #8540 (got 17 columns instead of 14)
#     Line #8541 (got 24 columns instead of 14)
#     Line #8542 (got 16 columns instead of 14)
#     Line #8543 (got 27 columns instead of 14)
#     Line #8544 (got 23 columns instead of 14)
#     Line #8545 (got 15 columns instead of 14)
#     Line #8546 (got 25 columns instead of 14)
#     Line #8547 (got 21 columns instead of 14)
#     Line #8548 (got 19 columns instead of 14)
#     Line #8549 (got 15 columns instead of 14)
#     Line #8550 (got 23 columns instead of 14)
#     Line #8551 (got 15 columns instead of 14)
#     Line #8552 (got 23 columns instead of 14)
#     Line #8553 (got 18 columns instead of 14)
#     Line #8554 (got 20 columns instead of 14)
#     Line #8555 (got 13 columns instead of 14)
#     Line #8556 (got 25 columns instead of 14)
#     Line #8557 (got 24 columns instead of 14)
#     Line #8558 (got 23 columns instead of 14)
#     Line #8559 (got 23 columns instead of 14)
#     Line #8560 (got 26 columns instead of 14)
#     Line #8561 (got 27 columns instead of 14)
#     Line #8562 (got 26 columns instead of 14)
#     Line #8563 (got 24 columns instead of 14)
#     Line #8564 (got 22 columns instead of 14)
#     Line #8566 (got 25 columns instead of 14)
#     Line #8567 (got 24 columns instead of 14)
#     Line #8568 (got 25 columns instead of 14)
#     Line #8570 (got 20 columns instead of 14)
#     Line #8571 (got 23 columns instead of 14)
#     Line #8572 (got 23 columns instead of 14)
#     Line #8573 (got 24 columns instead of 14)
#     Line #8574 (got 13 columns instead of 14)
#     Line #8575 (got 23 columns instead of 14)
#     Line #8576 (got 16 columns instead of 14)
#     Line #8577 (got 13 columns instead of 14)
#     Line #8578 (got 41 columns instead of 14)
#     Line #8579 (got 21 columns instead of 14)
#     Line #8580 (got 21 columns instead of 14)
#     Line #8581 (got 17 columns instead of 14)
#     Line #8582 (got 22 columns instead of 14)
#     Line #8583 (got 27 columns instead of 14)
#     Line #8584 (got 33 columns instead of 14)
#     Line #8585 (got 25 columns instead of 14)
#     Line #8586 (got 22 columns instead of 14)
#     Line #8587 (got 28 columns instead of 14)
#     Line #8588 (got 24 columns instead of 14)
#     Line #8589 (got 23 columns instead of 14)
#     Line #8590 (got 22 columns instead of 14)
#     Line #8591 (got 17 columns instead of 14)
#     Line #8592 (got 25 columns instead of 14)
#     Line #8593 (got 18 columns instead of 14)
#     Line #8594 (got 21 columns instead of 14)
#     Line #8595 (got 20 columns instead of 14)
#     Line #8596 (got 23 columns instead of 14)
#     Line #8597 (got 18 columns instead of 14)
#     Line #8598 (got 29 columns instead of 14)
#     Line #8599 (got 23 columns instead of 14)
#     Line #8600 (got 20 columns instead of 14)
#     Line #8601 (got 16 columns instead of 14)
#     Line #8602 (got 30 columns instead of 14)
#     Line #8603 (got 22 columns instead of 14)
#     Line #8604 (got 22 columns instead of 14)
#     Line #8605 (got 18 columns instead of 14)
#     Line #8606 (got 21 columns instead of 14)
#     Line #8607 (got 24 columns instead of 14)
#     Line #8608 (got 20 columns instead of 14)
#     Line #8610 (got 22 columns instead of 14)
#     Line #8611 (got 24 columns instead of 14)
#     Line #8612 (got 22 columns instead of 14)
#     Line #8614 (got 24 columns instead of 14)
#     Line #8615 (got 23 columns instead of 14)
#     Line #8616 (got 21 columns instead of 14)
#     Line #8617 (got 22 columns instead of 14)
#     Line #8618 (got 27 columns instead of 14)
#     Line #8619 (got 27 columns instead of 14)
#     Line #8620 (got 23 columns instead of 14)
#     Line #8621 (got 26 columns instead of 14)
#     Line #8622 (got 22 columns instead of 14)
#     Line #8623 (got 15 columns instead of 14)
#     Line #8624 (got 15 columns instead of 14)
#     Line #8625 (got 27 columns instead of 14)
#     Line #8626 (got 22 columns instead of 14)
#     Line #8627 (got 24 columns instead of 14)
#     Line #8628 (got 25 columns instead of 14)
#     Line #8629 (got 25 columns instead of 14)
#     Line #8630 (got 26 columns instead of 14)
#     Line #8631 (got 23 columns instead of 14)
#     Line #8632 (got 28 columns instead of 14)
#     Line #8633 (got 30 columns instead of 14)
#     Line #8634 (got 21 columns instead of 14)
#     Line #8636 (got 19 columns instead of 14)
#     Line #8637 (got 18 columns instead of 14)
#     Line #8638 (got 21 columns instead of 14)
#     Line #8639 (got 22 columns instead of 14)
#     Line #8640 (got 24 columns instead of 14)
#     Line #8641 (got 24 columns instead of 14)
#     Line #8642 (got 28 columns instead of 14)
#     Line #8643 (got 22 columns instead of 14)
#     Line #8644 (got 21 columns instead of 14)
#     Line #8645 (got 27 columns instead of 14)
#     Line #8646 (got 21 columns instead of 14)
#     Line #8647 (got 16 columns instead of 14)
#     Line #8648 (got 42 columns instead of 14)
#     Line #8649 (got 21 columns instead of 14)
#     Line #8650 (got 15 columns instead of 14)
#     Line #8651 (got 24 columns instead of 14)
#     Line #8652 (got 21 columns instead of 14)
#     Line #8653 (got 18 columns instead of 14)
#     Line #8654 (got 16 columns instead of 14)
#     Line #8655 (got 17 columns instead of 14)
#     Line #8656 (got 29 columns instead of 14)
#     Line #8657 (got 23 columns instead of 14)
#     Line #8658 (got 23 columns instead of 14)
#     Line #8659 (got 25 columns instead of 14)
#     Line #8660 (got 13 columns instead of 14)
#     Line #8661 (got 25 columns instead of 14)
#     Line #8662 (got 28 columns instead of 14)
#     Line #8663 (got 24 columns instead of 14)
#     Line #8665 (got 25 columns instead of 14)
#     Line #8666 (got 23 columns instead of 14)
#     Line #8667 (got 24 columns instead of 14)
#     Line #8668 (got 26 columns instead of 14)
#     Line #8669 (got 23 columns instead of 14)
#     Line #8670 (got 18 columns instead of 14)
#     Line #8671 (got 23 columns instead of 14)
#     Line #8672 (got 27 columns instead of 14)
#     Line #8673 (got 25 columns instead of 14)
#     Line #8674 (got 23 columns instead of 14)
#     Line #8675 (got 20 columns instead of 14)
#     Line #8676 (got 21 columns instead of 14)
#     Line #8678 (got 27 columns instead of 14)
#     Line #8679 (got 21 columns instead of 14)
#     Line #8680 (got 25 columns instead of 14)
#     Line #8681 (got 13 columns instead of 14)
#     Line #8682 (got 24 columns instead of 14)
#     Line #8683 (got 20 columns instead of 14)
#     Line #8684 (got 23 columns instead of 14)
#     Line #8685 (got 24 columns instead of 14)
#     Line #8686 (got 23 columns instead of 14)
#     Line #8687 (got 23 columns instead of 14)
#     Line #8688 (got 23 columns instead of 14)
#     Line #8689 (got 25 columns instead of 14)
#     Line #8690 (got 21 columns instead of 14)
#     Line #8691 (got 23 columns instead of 14)
#     Line #8692 (got 21 columns instead of 14)
#     Line #8693 (got 25 columns instead of 14)
#     Line #8694 (got 20 columns instead of 14)
#     Line #8695 (got 23 columns instead of 14)
#     Line #8696 (got 15 columns instead of 14)
#     Line #8697 (got 21 columns instead of 14)
#     Line #8698 (got 28 columns instead of 14)
#     Line #8699 (got 23 columns instead of 14)
#     Line #8700 (got 30 columns instead of 14)
#     Line #8701 (got 23 columns instead of 14)
#     Line #8702 (got 23 columns instead of 14)
#     Line #8703 (got 16 columns instead of 14)
#     Line #8704 (got 15 columns instead of 14)
#     Line #8705 (got 13 columns instead of 14)
#     Line #8706 (got 19 columns instead of 14)
#     Line #8707 (got 26 columns instead of 14)
#     Line #8708 (got 20 columns instead of 14)
#     Line #8709 (got 26 columns instead of 14)
#     Line #8710 (got 24 columns instead of 14)
#     Line #8711 (got 16 columns instead of 14)
#     Line #8712 (got 26 columns instead of 14)
#     Line #8713 (got 22 columns instead of 14)
#     Line #8714 (got 23 columns instead of 14)
#     Line #8715 (got 24 columns instead of 14)
#     Line #8716 (got 16 columns instead of 14)
#     Line #8717 (got 24 columns instead of 14)
#     Line #8718 (got 23 columns instead of 14)
#     Line #8719 (got 26 columns instead of 14)
#     Line #8720 (got 25 columns instead of 14)
#     Line #8721 (got 21 columns instead of 14)
#     Line #8722 (got 16 columns instead of 14)
#     Line #8723 (got 24 columns instead of 14)
#     Line #8724 (got 23 columns instead of 14)
#     Line #8725 (got 21 columns instead of 14)
#     Line #8726 (got 25 columns instead of 14)
#     Line #8728 (got 25 columns instead of 14)
#     Line #8729 (got 23 columns instead of 14)
#     Line #8730 (got 27 columns instead of 14)
#     Line #8731 (got 18 columns instead of 14)
#     Line #8732 (got 17 columns instead of 14)
#     Line #8733 (got 29 columns instead of 14)
#     Line #8734 (got 23 columns instead of 14)
#     Line #8735 (got 28 columns instead of 14)
#     Line #8736 (got 24 columns instead of 14)
#     Line #8737 (got 25 columns instead of 14)
#     Line #8738 (got 17 columns instead of 14)
#     Line #8739 (got 25 columns instead of 14)
#     Line #8740 (got 22 columns instead of 14)
#     Line #8742 (got 18 columns instead of 14)
#     Line #8744 (got 16 columns instead of 14)
#     Line #8745 (got 15 columns instead of 14)
#     Line #8746 (got 25 columns instead of 14)
#     Line #8747 (got 21 columns instead of 14)
#     Line #8748 (got 15 columns instead of 14)
#     Line #8749 (got 26 columns instead of 14)
#     Line #8750 (got 18 columns instead of 14)
#     Line #8751 (got 13 columns instead of 14)
#     Line #8752 (got 22 columns instead of 14)
#     Line #8753 (got 25 columns instead of 14)
#     Line #8754 (got 23 columns instead of 14)
#     Line #8755 (got 26 columns instead of 14)
#     Line #8756 (got 28 columns instead of 14)
#     Line #8757 (got 22 columns instead of 14)
#     Line #8758 (got 23 columns instead of 14)
#     Line #8759 (got 15 columns instead of 14)
#     Line #8760 (got 15 columns instead of 14)
#     Line #8761 (got 27 columns instead of 14)
#     Line #8762 (got 17 columns instead of 14)
#     Line #8764 (got 28 columns instead of 14)
#     Line #8765 (got 22 columns instead of 14)
#     Line #8766 (got 24 columns instead of 14)
#     Line #8767 (got 13 columns instead of 14)
#     Line #8768 (got 26 columns instead of 14)
#     Line #8769 (got 28 columns instead of 14)
#     Line #8770 (got 23 columns instead of 14)
#     Line #8771 (got 23 columns instead of 14)
#     Line #8772 (got 30 columns instead of 14)
#     Line #8773 (got 33 columns instead of 14)
#     Line #8774 (got 23 columns instead of 14)
#     Line #8775 (got 23 columns instead of 14)
#     Line #8776 (got 25 columns instead of 14)
#     Line #8777 (got 20 columns instead of 14)
#     Line #8778 (got 27 columns instead of 14)
#     Line #8779 (got 23 columns instead of 14)
#     Line #8780 (got 25 columns instead of 14)
#     Line #8781 (got 20 columns instead of 14)
#     Line #8782 (got 22 columns instead of 14)
#     Line #8783 (got 19 columns instead of 14)
#     Line #8784 (got 20 columns instead of 14)
#     Line #8785 (got 22 columns instead of 14)
#     Line #8786 (got 26 columns instead of 14)
#     Line #8787 (got 19 columns instead of 14)
#     Line #8788 (got 19 columns instead of 14)
#     Line #8789 (got 19 columns instead of 14)
#     Line #8790 (got 20 columns instead of 14)
#     Line #8791 (got 26 columns instead of 14)
#     Line #8792 (got 28 columns instead of 14)
#     Line #8793 (got 25 columns instead of 14)
#     Line #8794 (got 23 columns instead of 14)
#     Line #8795 (got 24 columns instead of 14)
#     Line #8796 (got 19 columns instead of 14)
#     Line #8797 (got 25 columns instead of 14)
#     Line #8798 (got 27 columns instead of 14)
#     Line #8799 (got 20 columns instead of 14)
#     Line #8800 (got 33 columns instead of 14)
#     Line #8801 (got 23 columns instead of 14)
#     Line #8802 (got 24 columns instead of 14)
#     Line #8803 (got 21 columns instead of 14)
#     Line #8804 (got 27 columns instead of 14)
#     Line #8805 (got 22 columns instead of 14)
#     Line #8806 (got 25 columns instead of 14)
#     Line #8807 (got 16 columns instead of 14)
#     Line #8808 (got 21 columns instead of 14)
#     Line #8809 (got 23 columns instead of 14)
#     Line #8810 (got 23 columns instead of 14)

# %% [markdown]
# ## Github 101
#
# ```shell
# # Repartir sur une nouvelle branche
# git checkout main
# # Mettre à jour notre branche locale
# git pull origin main
# # Recréer une branche pour le TD 05
# git checkout -b branch_name_td05
# # Dupliquer le fichier du td et rajouter en suffix son nom
# cd 'chemin/m1-miage/'
# cp 'src/to_do/td_05/td_05.ipynb' 'src/done/td_05/td_05_nom_prenom.ipynb'
# # Faire le travail necessaire sur votre fichier et commit et push
# git add 'src/done/td_05/td_05_nom_prenom.ipynb'
# git commit -m 'message descriptif du travail fait'
# git push --set-upstream origin nom_branche
# # Faire une pull request
# ```
#
# [>>>PULL REQUEST<<<](https://github.com/lapointe05/m1-miage/pulls)
